# %% [markdown]
# # Extract, Transform and Load (ETL)
# ----------------------
#
# ### Data Fundamentals con Python
#
# #### Enero 2023
#
# **Aurora Cobo Aguilera**
#
# **The Valley**
#
# ----------------------

# %% [markdown]
# ## Ejemplo 1
# Vamos a ver un ejemplo de lo que sería una ETL. Imaginad que tenemos un csv con los siguientes campos:
#
# 1. work_year
# 2. experience_level
# 3. employment_type
# 4. job_title
# 5. salary
# 6. salary_currency
# 7. salary_in_usd
# 8. employee_residence
# 9. remote_ratio
# 10. company_location
# 11. company_size
#
#
# Un ejemplo de una fila del csv podria ser:

# %%
lineaOrigen = '88,2021,SE,FT,Lead Data Analyst,170000,USD,170000,US,100,US,L'

# %% [markdown]
# El objetivo de una ETL es cargar todas las líneas de un fichero y convertirlas o procesarlas para darles el formato que nosotros queramos. Después, debemos guardar esas nuevas líneas convertidas.
#
# Es decir,
#
# 1. Cargar fila
# 2. Transformar fila
# 3. Guardar fila

# %% [markdown]
# Lo primero que has de hacer es identificar cada item de la secuencia de texto con los campos del fichero.

# %% [markdown]
# Una herramienta de utilidad de Python dentro del procesado de cadenas de texto es la función *split()*, ésta permite convertir un texto en una lista en la que cada elemento de la lista es un fragmento del texto original. Los fragmentos se seleccionan en función de un carácter definido que se pasa como parámetro.
#
# Por ejemplo, vamos a separar nuestra cadena con el carácter ','.

# %%
lineaOrigen = lineaOrigen.split(',')

# %% [markdown]
# Ahora, *lineaOrigen* ha pasado a ser una lista con cada uno de los campos. Esta instrucción es muy frecuente pues es muy común encontrar ficheros que separar los elementos con comas.

# %%
print(lineaOrigen)
# Out:
# ['88', '2021', 'SE', 'FT', 'Lead Data Analyst', '170000', 'USD', '170000', 'US', '100', 'US', 'L']

# %% [markdown]
# Si nos fijamos, esta lista tiene

# %%
print(len(lineaOrigen))
# Out:
# 12

# %% [markdown]
# elementos. Mientras que nosotros habíamos definido 11 campos.
#
# > **Ejercicio**: ¿Qué puede significar el elemento sobrante? ¿Cuál de todos ellos es?

# %% [markdown]
# ### Manipulación de la experiencia
#
# Vamos a leer y procesar los campos de interés. Por ejemplo, el campo *experiencia*, puede tener 4 valores posibles (en, mi, se, ex). Una forma de procesarlo sería **codificarlo**.

# %%
experiencia = lineaOrigen[2]

if(experiencia.lower() == 'en'):
    experiencia = 0
elif(experiencia.lower() == 'mi'):
    experiencia = 1
elif(experiencia.lower() == 'se'):
    experiencia = 2
elif(experiencia.lower() == 'ex'):
    experiencia = 3
else:
    experiencia = -1

# %% [markdown]
# En caso de no encontrar ninguno de los caso posibles, nos encontraremos ante un **valor nulo** que hemos decidido codificar con ...
#
# > **Ejercicio**: ¿Con qué valor codificamos los nulos en el ejemplo anterior?

# %% [markdown]
# En este ejemplo, el campo experiencia pasa a valer:

# %%
print(experiencia)
# Out:
# 2

# %% [markdown]
# ### Manipulación del salario
#
# Otro campo que nos interesa es el del salario. Así que primero lo identificamos y guardamos.

# %%
moneda = lineaOrigen[6]
print(moneda)
# Out:
# USD

# %% [markdown]
# Exacto! Este campo indica el tipo de moneda en el que está recogido la cantidad salarial. También tiene una serie posible de valores (EUR, GBP, USD).
#
# > **Ejercicio**: ¿Cómo denominamos en teoría a estas variables que sólo pueden obtener un conjunto finito de valores?

# %% [markdown]
# Ahora, vamos a unificar la cantidad de salario a euros. Como podemos encontrar salarios en diferentes tipos de monedas, nos interesa que todos estén en la misma para poder comparar y operar de manera correcta. Es como una manera de unificar el sistema de medida. Para ello, mira cuál es el cambio de moneda de hoy en google para las libras y los dólares y pásalo todo a euros.

# %%
if(moneda.lower() == 'eur'):
    salario =  float(lineaOrigen[5]) # <SOL>
elif(moneda.lower() == 'gbp'):
    salario = float(lineaOrigen[5]) * 1.13 # <SOL>
elif(moneda.lower() == 'usd'):
    salario =  float(lineaOrigen[5]) * 0.91 # <SOL>
else:
    salario = -1

print(salario)
# Out:
# 154700.0

# %% [markdown]
# ### Manipulación del campo *remote*
#
# El campo *remote* hemos decidido dejarlo tal cual.

# %%
remote = int(lineaOrigen[-3])
print(remote)
# Out:
# 100

# %% [markdown]
# ### Manipulación del tamaño
# Por último, nos interesa quedarnos con el campo *company_size*.
#
# > **Ejercicio**: A continuación, obtén dicho campo y guárdalo en alguna variable.

# %%
#<SOL>
tamanyo = lineaOrigen[-1]
print(tamanyo)
#</SOL>
# Out:
# L

# %% [markdown]
# > **Ejercicio**: Para preprocesarlo, codifícalo de manera análoga a los casos anteriores, teniendo en cuenta que los valores posibles son 's', 'm' y 'l', a los que les daremos los valores 0, 1 y 2 respectivamente. -1 de nuevo se usa en caso de que ninguno de los anteriores se dé.

# %%
# <SOL>
if(tamanyo.lower() == 's'):
    tamanyo = 0
elif(tamanyo.lower() == 'm'):
    tamanyo = 1
elif(tamanyo.lower() == 'l'):
    tamanyo = 2
else:
    tamanyo = -1
# <\SOL>

# %%
lineaDestino = [experiencia, salario, remote, tamanyo]
print(lineaDestino)
# Out:
# [2, 154700.0, 100, 2]

# %% [markdown]
# El resultado final debería ser un vector de 4 números, que podría ser la entrada de cualquier modelo de Machine Learning.

# %% [markdown]
# ## Ejemplo 2
#
# A continuación vamos a ver otro ejemplo que vamos a leer del siguiente enlace:
#
# https://www.kaggle.com/datasets/abecklas/fifa-world-cup?select=WorldCupPlayers.csv
#
# Como podrás comprobar, este dataset contiene datos de los jugadores del mundial de fútbol.
#
# > **Ejercicio**: Vamos a aprovechar para registrarnos en kaggle y jugar con la plataforma!

# %% [markdown]
# Fíjate ahora en la descripción de los campos del mismo:
#
# 'RoundID, MatchID, Team Initials, Coach Name, Line-up, Shirt Number, Player Name, Position, Event'
#
# > **Ejercicio**: Descárgate el dataset y abre el fichero referente a los jugadores (WorldCupPlayers.csv). A continuación, elige una línea cualquiera del fichero y cópiala en la siguiente celda en <PEGA AQUÍ>, entre comillas dobles.

# %%
lineaOrigen =  "201,1096,FRA,CAUDRON Raoul (FRA),S,0,Andre MASCHINOT,,G43' G87'" #<PEGA AQUÍ>

# %% [markdown]
# Estamos interesados en recolectar y procesar 3 campos, el país del jugador, el nombre y el número de goles que ha metido. Fíjate en la información de cada campo y extrae de la variable *lineaOrigen* dicha información. Pero, vayamos por partes.
#
# > **Ejercicio**: Primero divide el string en una lista donde cada elemento es uno de los campos. Recuerda que puedes usar la función *split*.

# %%
#<SOL>
lineaOrigen = lineaOrigen.split(',')
print(lineaOrigen)
#</SOL>
# Out:
# ['201', '1096', 'FRA', 'CAUDRON Raoul (FRA)', 'S', '0', 'Andre MASCHINOT', '', "G43' G87'"]

# %% [markdown]
# > **Ejercicio**: Ahora guarda el país del jugador y muéstralo con print.

# %%
#<SOL>
pais = lineaOrigen[2]
print(pais)
#</SOL>
# Out:
# FRA

# %% [markdown]
# > **Ejercicio**: Haz lo mismo con el nombre, pero pásalo entero a minúsculas. Guárdalo en la variable 'nombre'.

# %%
#<SOL>
nombre = lineaOrigen[-3].lower()
print(nombre)
#</SOL>
# Out:
# andre maschinot

# %% [markdown]
# > **Ejercicio**: Por último, extrae los goles. Investiga cómo se indica un gol y piensa la manera de contar el total de éstos y guárdalos en una variable llamada 'goles'.

# %%
#<SOL>
eventos = lineaOrigen[-1]

num_goles = 0
for caracter in eventos:
  if caracter == 'G':
    num_goles = num_goles +1
print(num_goles)

#</SOL>
# Out:
# 2

# %%
goles = len(eventos.split('G') )-1
print(goles)
# Out:
# 2

# %%
#<SOL>
# Más avanzada
goles = len(eventos.split('G') )-1
restar_golesPropia = len(eventos.split('OG') )-1
sumar_golesPenalti = len(eventos.split('P') )-1
restar_golesPenalti = len(eventos.split('MP') )-1
goles = goles - restar_golesPropia + sumar_golesPenalti - restar_golesPenalti
print(goles)
#</SOL>
# Out:
# 2

# %% [markdown]
# Comprueba que todo ha ido correctamente ejecutando la siguiente línea donde concatena los campos de interés para calcular el resultado final.

# %%
lineaDestino = [pais,nombre,goles]
print(lineaDestino)
# Out:
# ['FRA', 'andre maschinot', 2]

# %% [markdown]
# ## Ejemplo 3
#
# En este ejemplo vamos a tratar un dataset de Población Mundial, del que puedes extraer toda la información en el siguiente enlace:
#
# https://www.kaggle.com/datasets/ahmadjalalmasood123/world-population-dataset
#
# De la misma manera que antes, podemos obtener los nombres de los campos en la primera fila del fichero:
#
# ##### #,Country (or dependency),Population (2022),Yearly change,Net change,Density (P/Km²),Land Area (Km²),Migrants (net),Fert. Rate,Med.Age,Urban Pop %,World Share
#
# En este caso, hemos sustituido las comas de separación por punto y coma para no confundirlas con la coma numérica.

# %%
lineaOrigen = '1;China;1,439,323,776;0.39%;5,540,090;153;9,388,211;-348,399;1.7;38;61%;18.47%'

# %% [markdown]
# Por tanto, ahora el split lo hacemos con ;.

# %%
lineaOrigen = lineaOrigen.split(';')
print(lineaOrigen)
# Out:
# ['1', 'China', '1,439,323,776', '0.39%', '5,540,090', '153', '9,388,211', '-348,399', '1.7', '38', '61%', '18.47%']

# %% [markdown]
# Accedamos al país.

# %%
pais = lineaOrigen[1].lower()
print(pais)
# Out:
# china

# %% [markdown]
# Ahora, a la población, teniendo en cuenta que es un string y que para convertirlo a entero y no confundir las comas por comas decimales, hay que eliminarlas.

# %%
print(lineaOrigen[2].replace(',',''))
print(type(lineaOrigen[2].replace(',','')))
# Out:
# 1439323776
# <class 'str'>

# %%
poblacion = int(lineaOrigen[2].replace(',',''))
print(poblacion)
print(type(poblacion))
# Out:
# 1439323776
# <class 'int'>

# %% [markdown]
# Igual con el cambio, campo *Net change*.

# %%
cambioTotal = int(lineaOrigen[4].replace(',',''))
print(cambioTotal)
# Out:
# 5540090

# %% [markdown]
# El signo indica si la población ha cambiado para crecer o decrecer.

# %%
signo = -1

if(cambioTotal > 0):
  signo = 1
print(signo)
# Out:
# 1

# %% [markdown]
# Para la tasa de fertilidad, la vamos a codificar.

# %%
fertil = float(lineaOrigen[-4])

if( fertil > 0 and fertil <= 1):
  fertil = 10
elif( fertil > 1 and fertil <= 1.5):
  fertil = 7.5
elif( fertil > 1.5 and fertil <= 2.1):
  fertil = 5
elif( fertil > 2.1 and fertil <= 3):
  fertil = 4
else:
  fertil = 0

print(fertil)
# Out:
# 5

# %% [markdown]
# > **Ejercicio**: Queremos calcular el número de personas según la densidad de población. Para ello, multiplica la densidad (personas por kilómetro cuadrado) por el tamaño del país.

# %%
personasKPI =  int(lineaOrigen[5].replace(',','')) * int(lineaOrigen[6].replace(',','')) #pasar . a , e int       #<SOL>
print(personasKPI)
# Out:
# 1436396283

# %% [markdown]
# > **Ejercicio**: Por último, guarda el porcentaje de población mundial. Hazlo sin el símbolo de porcentaje (%) y en un número float.

# %%
porcentajeMundial = float(lineaOrigen[-1].replace('%',''))#<SOL> #2
#porcentajeMundial = float(lineaOrigen[-1][:-1])     #<SOL> #1
print(porcentajeMundial)
# Out:
# 18.47

# %% [markdown]
# Comprobemos el resultado.

# %%
lineaDestino = [pais, poblacion, cambioTotal, signo, personasKPI, fertil, porcentajeMundial]
print(lineaDestino)
# Resultado esperado:
#  china, int(1439323776), int(5540090), 1, 1436396283, 5, 18.47
# Out:
# ['china', 1439323776, 5540090, 1, 1436396283, 5, 18.47]

# %% [markdown]
# > ## Ejercicio
#
# Repite el mismo procedimiento en el siguiente dataset:
#
# https://www.kaggle.com/datasets/nathanlauga/nba-games?select=games.csv
#
#
# Para ello utiliza la siguiente línea ejemplo del fichero *games.csv*.

# %%
rawLine = ["2021-11-17","22100213","Final","1610612766","1610612764","2021","1610612766","97","0.438","0.5","0.313","30","59","1610612764","87","0.367","0.813","0.19","23","48","1"]

# %% [markdown]
# Deberás extraer la fecha, la puntuación del equipo local, la puntuación del visitante y el ganador.

# %%
#<SOL>

#</SOL>

# %%
output = [fecha, puntuacionLocal, puntuacionVisitante, ganador]
print(output)

# %% [markdown]
# ## Leer ficheros
#
# Es momento de aprender a leer un fichero. Para ello primero tenemos que descargar el fichero deseado, luego cargarlo en el espacio de trabajo del notebook y por último podremos leerlo en python.

# %% [markdown]
# Si ya has hecho los dos primeros pasos, vamos a leer el fichero utilizando una librería llamada *csv*, que tendremos que importar. El resto de líneas también se suelen repetir, puedes reutilizarlas en el futuro. Tendrás que cambiar 'nombreDelFichero.csv' por el deseado y quizás algún parámetro como el que indica el carácter delimitante. Siempre que usemos un archivo csv, el carácter para delimitar suele ser la coma.

# %%
import csv
with open('World Population (2022) .csv', newline='') as csvfile:  #with open('nombreDelFichero.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        print(row)
# Out:
# ['\ufeff#', 'Country (or dependency)', 'Population (2022)', 'Yearly change', 'Net change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)', 'Fert. Rate', 'Med.Age', 'Urban Pop %', 'World Share']
# ['1', 'China', '"1', '439', '323', '776"', '0.39%', '"5', '540', '090"', '153', '"9', '388', '211"', '"-348', '399"', '1.7', '38', '61%', '18.47%']
# ['2', 'India', '"1', '380', '004', '385"', '0.99%', '"13', '586', '631"', '464', '"2', '973', '190"', '"-532', '687"', '2.2', '28', '35%', '17.70%']
# ['3', 'United States', '"331', '002', '651"', '0.59%', '"1', '937', '734"', '36', '"9', '147', '420"', '"954', '806"', '1.8', '38', '83%', '4.25%']
# ['4', 'Indonesia', '"273', '523', '615"', '1.07%', '"2', '898', '047"', '151', '"1', '811', '570"', '"-98', '955"', '2.3', '30', '56%', '3.51%']
# ['5', 'Pakistan', '"220', '892', '340"', '2.00%', '"4', '327', '022"', '287', '"770', '880"', '"-233', '379"', '3.6', '23', '35%', '2.83%']
# ['6', 'Brazil', '"212', '559', '417"', '0.72%', '"1', '509', '890"', '25', '"8', '358', '140"', '"21', '200"', '1.7', '33', '88%', '2.73%']
# ['7', 'Nigeria', '"206', '139', '589"', '2.58%', '"5', '175', '990"', '226', '"910', '770"', '"-60', '000"', '5.4', '18', '52%', '2.64%']
# ['8', 'Bangladesh', '"164', '689', '383"', '1.01%', '"1', '643', '222"', '"1', '265"', '"130', '170"', '"-369', '501"', '2.1', '28', '39%', '2.11%']
# ['9', 'Russia', '"145', '934', '462"', '0.04%', '"62', '206"', '9', '"16', '376', '870"', '"182', '456"', '1.8', '40', '74%', '1.87%']
# ['10', 'Mexico', '"128', '932', '753"', '1.06%', '"1', '357', '224"', '66', '"1', '943', '950"', '"-60', '000"', '2.1', '29', '84%', '1.65%']
# ['11', 'Japan', '"126', '476', '461"', '-0.30%', '"-383', '840"', '347', '"364', '555"', '"71', '560"', '1.4', '48', '92%', '1.62%']
# ['12', 'Ethiopia', '"114', '963', '588"', '2.57%', '"2', '884', '858"', '115', '"1', '000', '000"', '"30', '000"', '4.3', '19', '21%', '1.47%']
# ['13', 'Philippines', '"109', '581', '078"', '1.35%', '"1', '464', '463"', '368', '"298', '170"', '"-67', '152"', '2.6', '26', '47%', '1.41%']
# ['14', 'Egypt', '"102', '334', '404"', '1.94%', '"1', '946', '331"', '103', '"995', '450"', '"-38', '033"', '3.3', '25', '43%', '1.31%']
# ['15', 'Vietnam', '"97', '338', '579"', '0.91%', '"876', '473"', '314', '"310', '070"', '"-80', '000"', '2.1', '32', '38%', '1.25%']
# ['16', 'DR Congo', '"89', '561', '403"', '3.19%', '"2', '770', '836"', '40', '"2', '267', '050"', '"23', '861"', '6', '17', '46%', '1.15%']
# ['17', 'Turkey', '"84', '339', '067"', '1.09%', '"909', '452"', '110', '"769', '630"', '"283', '922"', '2.1', '32', '76%', '1.08%']
# ['18', 'Iran', '"83', '992', '949"', '1.30%', '"1', '079', '043"', '52', '"1', '628', '550"', '"-55', '000"', '2.2', '32', '76%', '1.08%']
# ['19', 'Germany', '"83', '783', '942"', '0.32%', '"266', '897"', '240', '"348', '560"', '"543', '822"', '1.6', '46', '76%', '1.07%']
# ['20', 'Thailand', '"69', '799', '978"', '0.25%', '"174', '396"', '137', '"510', '890"', '"19', '444"', '1.5', '40', '51%', '0.90%']
# ['21', 'United Kingdom', '"67', '886', '011"', '0.53%', '"355', '839"', '281', '"241', '930"', '"260', '650"', '1.8', '40', '83%', '0.87%']
# ['22', 'France', '"65', '273', '511"', '0.22%', '"143', '783"', '119', '"547', '557"', '"36', '527"', '1.9', '42', '82%', '0.84%']
# ['23', 'Italy', '"60', '461', '826"', '-0.15%', '"-88', '249"', '206', '"294', '140"', '"148', '943"', '1.3', '47', '69%', '0.78%']
# ['24', 'Tanzania', '"59', '734', '218"', '2.98%', '"1', '728', '755"', '67', '"885', '800"', '"-40', '076"', '4.9', '18', '37%', '0.77%']
# ['25', 'South Africa', '"59', '308', '690"', '1.28%', '"750', '420"', '49', '"1', '213', '090"', '"145', '405"', '2.4', '28', '67%', '0.76%']
# ['26', 'Myanmar', '"54', '409', '800"', '0.67%', '"364', '380"', '83', '"653', '290"', '"-163', '313"', '2.2', '29', '31%', '0.70%']
# ['27', 'Kenya', '"53', '771', '296"', '2.28%', '"1', '197', '323"', '94', '"569', '140"', '"-10', '000"', '3.5', '20', '28%', '0.69%']
# ['28', 'South Korea', '"51', '269', '185"', '0.09%', '"43', '877"', '527', '"97', '230"', '"11', '731"', '1.1', '44', '82%', '0.66%']
# ['29', 'Colombia', '"50', '882', '891"', '1.08%', '"543', '448"', '46', '"1', '109', '500"', '"204', '796"', '1.8', '31', '80%', '0.65%']
# ['30', 'Spain', '"46', '754', '778"', '0.04%', '"18', '002"', '94', '"498', '800"', '"40', '000"', '1.3', '45', '80%', '0.60%']
# ['31', 'Uganda', '"45', '741', '007"', '3.32%', '"1', '471', '413"', '229', '"199', '810"', '"168', '694"', '5', '17', '26%', '0.59%']
# ['32', 'Argentina', '"45', '195', '774"', '0.93%', '"415', '097"', '17', '"2', '736', '690"', '"4', '800"', '2.3', '32', '93%', '0.58%']
# ['33', 'Algeria', '"43', '851', '044"', '1.85%', '"797', '990"', '18', '"2', '381', '740"', '"-10', '000"', '3.1', '29', '73%', '0.56%']
# ['34', 'Sudan', '"43', '849', '260"', '2.42%', '"1', '036', '022"', '25', '"1', '765', '048"', '"-50', '000"', '4.4', '20', '35%', '0.56%']
# ['35', 'Ukraine', '"43', '733', '762"', '-0.59%', '"-259', '876"', '75', '"579', '320"', '"10', '000"', '1.4', '41', '69%', '0.56%']
# ['36', 'Iraq', '"40', '222', '493"', '2.32%', '"912', '710"', '93', '"434', '320"', '"7', '834"', '3.7', '21', '73%', '0.52%']
# ['37', 'Afghanistan', '"38', '928', '346"', '2.33%', '"886', '592"', '60', '"652', '860"', '"-62', '920"', '4.6', '18', '25%', '0.50%']
# ['38', 'Poland', '"37', '846', '611"', '-0.11%', '"-41', '157"', '124', '"306', '230"', '"-29', '395"', '1.4', '42', '60%', '0.49%']
# ['39', 'Canada', '"37', '742', '154"', '0.89%', '"331', '107"', '4', '"9', '093', '510"', '"242', '032"', '1.5', '41', '81%', '0.48%']
# ['40', 'Morocco', '"36', '910', '560"', '1.20%', '"438', '791"', '83', '"446', '300"', '"-51', '419"', '2.4', '30', '64%', '0.47%']
# ['41', 'Saudi Arabia', '"34', '813', '871"', '1.59%', '"545', '343"', '16', '"2', '149', '690"', '"134', '979"', '2.3', '32', '84%', '0.45%']
# ['42', 'Uzbekistan', '"33', '469', '203"', '1.48%', '"487', '487"', '79', '"425', '400"', '"-8', '863"', '2.4', '28', '50%', '0.43%']
# ['43', 'Peru', '"32', '971', '854"', '1.42%', '"461', '401"', '26', '"1', '280', '000"', '"99', '069"', '2.3', '31', '79%', '0.42%']
# ['44', 'Angola', '"32', '866', '272"', '3.27%', '"1', '040', '977"', '26', '"1', '246', '700"', '"6', '413"', '5.6', '17', '67%', '0.42%']
# ['45', 'Malaysia', '"32', '365', '999"', '1.30%', '"416', '222"', '99', '"328', '550"', '"50', '000"', '2', '30', '78%', '0.42%']
# ['46', 'Mozambique', '"31', '255', '435"', '2.93%', '"889', '399"', '40', '"786', '380"', '"-5', '000"', '4.9', '18', '38%', '0.40%']
# ['47', 'Ghana', '"31', '072', '940"', '2.15%', '"655', '084"', '137', '"227', '540"', '"-10', '000"', '3.9', '22', '57%', '0.40%']
# ['48', 'Yemen', '"29', '825', '964"', '2.28%', '"664', '042"', '56', '"527', '970"', '"-30', '000"', '3.8', '20', '38%', '0.38%']
# ['49', 'Nepal', '"29', '136', '808"', '1.85%', '"528', '098"', '203', '"143', '350"', '"41', '710"', '1.9', '25', '21%', '0.37%']
# ['50', 'Venezuela', '"28', '435', '940"', '-0.28%', '"-79', '889"', '32', '"882', '050"', '"-653', '249"', '2.3', '30', 'N.A.', '0.36%']
# ['51', 'Madagascar', '"27', '691', '018"', '2.68%', '"721', '711"', '48', '"581', '795"', '"-1', '500"', '4.1', '20', '39%', '0.36%']
# ['52', 'Cameroon', '"26', '545', '863"', '2.59%', '"669', '483"', '56', '"472', '710"', '"-4', '800"', '4.6', '19', '56%', '0.34%']
# ['53', "Côte d'Ivoire", '"26', '378', '274"', '2.57%', '"661', '730"', '83', '"318', '000"', '"-8', '000"', '4.7', '19', '51%', '0.34%']
# ['54', 'North Korea', '"25', '778', '816"', '0.44%', '"112', '655"', '214', '"120', '410"', '"-5', '403"', '1.9', '35', '63%', '0.33%']
# ['55', 'Australia', '"25', '499', '884"', '1.18%', '"296', '686"', '3', '"7', '682', '300"', '"158', '246"', '1.8', '38', '86%', '0.33%']
# ['56', 'Niger', '"24', '206', '644"', '3.84%', '"895', '929"', '19', '"1', '266', '700"', '"4', '000"', '7', '15', '17%', '0.31%']
# ['57', 'Taiwan', '"23', '816', '775"', '0.18%', '"42', '899"', '673', '"35', '410"', '"30', '001"', '1.2', '42', '79%', '0.31%']
# ['58', 'Sri Lanka', '"21', '413', '249"', '0.42%', '"89', '516"', '341', '"62', '710"', '"-97', '986"', '2.2', '34', '18%', '0.27%']
# ['59', 'Burkina Faso', '"20', '903', '273"', '2.86%', '"581', '895"', '76', '"273', '600"', '"-25', '000"', '5.2', '18', '31%', '0.27%']
# ['60', 'Mali', '"20', '250', '833"', '3.02%', '"592', '802"', '17', '"1', '220', '190"', '"-40', '000"', '5.9', '16', '44%', '0.26%']
# ['61', 'Romania', '"19', '237', '691"', '-0.66%', '"-126', '866"', '84', '"230', '170"', '"-73', '999"', '1.6', '43', '55%', '0.25%']
# ['62', 'Malawi', '"19', '129', '952"', '2.69%', '"501', '205"', '203', '"94', '280"', '"-16', '053"', '4.3', '18', '18%', '0.25%']
# ['63', 'Chile', '"19', '116', '201"', '0.87%', '"164', '163"', '26', '"743', '532"', '"111', '708"', '1.7', '35', '85%', '0.25%']
# ['64', 'Kazakhstan', '"18', '776', '707"', '1.21%', '"225', '280"', '7', '"2', '699', '700"', '"-18', '000"', '2.8', '31', '58%', '0.24%']
# ['65', 'Zambia', '"18', '383', '955"', '2.93%', '"522', '925"', '25', '"743', '390"', '"-8', '000"', '4.7', '18', '45%', '0.24%']
# ['66', 'Guatemala', '"17', '915', '568"', '1.90%', '"334', '096"', '167', '"107', '160"', '"-9', '215"', '2.9', '23', '52%', '0.23%']
# ['67', 'Ecuador', '"17', '643', '054"', '1.55%', '"269', '392"', '71', '"248', '360"', '"36', '400"', '2.4', '28', '63%', '0.23%']
# ['68', 'Syria', '"17', '500', '658"', '2.52%', '"430', '523"', '95', '"183', '630"', '"-427', '391"', '2.8', '26', '60%', '0.22%']
# ['69', 'Netherlands', '"17', '134', '872"', '0.22%', '"37', '742"', '508', '"33', '720"', '"16', '000"', '1.7', '43', '92%', '0.22%']
# ['70', 'Senegal', '"16', '743', '927"', '2.75%', '"447', '563"', '87', '"192', '530"', '"-20', '000"', '4.7', '19', '49%', '0.21%']
# ['71', 'Cambodia', '"16', '718', '965"', '1.41%', '"232', '423"', '95', '"176', '520"', '"-30', '000"', '2.5', '26', '24%', '0.21%']
# ['72', 'Chad', '"16', '425', '864"', '3.00%', '"478', '988"', '13', '"1', '259', '200"', '"2', '000"', '5.8', '17', '23%', '0.21%']
# ['73', 'Somalia', '"15', '893', '222"', '2.92%', '"450', '317"', '25', '"627', '340"', '"-40', '000"', '6.1', '17', '47%', '0.20%']
# ['74', 'Zimbabwe', '"14', '862', '924"', '1.48%', '"217', '456"', '38', '"386', '850"', '"-116', '858"', '3.6', '19', '38%', '0.19%']
# ['75', 'Guinea', '"13', '132', '795"', '2.83%', '"361', '549"', '53', '"245', '720"', '"-4', '000"', '4.7', '18', '39%', '0.17%']
# ['76', 'Rwanda', '"12', '952', '218"', '2.58%', '"325', '268"', '525', '"24', '670"', '"-9', '000"', '4.1', '20', '18%', '0.17%']
# ['77', 'Benin', '"12', '123', '200"', '2.73%', '"322', '049"', '108', '"112', '760"', '"-2', '000"', '4.9', '19', '48%', '0.16%']
# ['78', 'Burundi', '"11', '890', '784"', '3.12%', '"360', '204"', '463', '"25', '680"', '"2', '001"', '5.5', '17', '14%', '0.15%']
# ['79', 'Tunisia', '"11', '818', '619"', '1.06%', '"123', '900"', '76', '"155', '360"', '"-4', '000"', '2.2', '33', '70%', '0.15%']
# ['80', 'Bolivia', '"11', '673', '021"', '1.39%', '"159', '921"', '11', '"1', '083', '300"', '"-9', '504"', '2.8', '26', '69%', '0.15%']
# ['81', 'Belgium', '"11', '589', '623"', '0.44%', '"50', '295"', '383', '"30', '280"', '"48', '000"', '1.7', '42', '98%', '0.15%']
# ['82', 'Haiti', '"11', '402', '528"', '1.24%', '"139', '451"', '414', '"27', '560"', '"-35', '000"', '3', '24', '57%', '0.15%']
# ['83', 'Cuba', '"11', '326', '616"', '-0.06%', '"-6', '867"', '106', '"106', '440"', '"-14', '400"', '1.6', '42', '78%', '0.15%']
# ['84', 'South Sudan', '"11', '193', '725"', '1.19%', '"131', '612"', '18', '"610', '952"', '"-174', '200"', '4.7', '19', '25%', '0.14%']
# ['85', 'Dominican Republic', '"10', '847', '910"', '1.01%', '"108', '952"', '225', '"48', '320"', '"-30', '000"', '2.4', '28', '85%', '0.14%']
# ['86', 'Czech Republic (Czechia)', '"10', '708', '981"', '0.18%', '"19', '772"', '139', '"77', '240"', '"22', '011"', '1.6', '43', '74%', '0.14%']
# ['87', 'Greece', '"10', '423', '054"', '-0.48%', '"-50', '401"', '81', '"128', '900"', '"-16', '000"', '1.3', '46', '85%', '0.13%']
# ['88', 'Jordan', '"10', '203', '134"', '1.00%', '"101', '440"', '115', '"88', '780"', '"10', '220"', '2.8', '24', '91%', '0.13%']
# ['89', 'Portugal', '"10', '196', '709"', '-0.29%', '"-29', '478"', '111', '"91', '590"', '"-6', '000"', '1.3', '46', '66%', '0.13%']
# ['90', 'Azerbaijan', '"10', '139', '177"', '0.91%', '"91', '459"', '123', '"82', '658"', '"1', '200"', '2.1', '32', '56%', '0.13%']
# ['91', 'Sweden', '"10', '099', '265"', '0.63%', '"62', '886"', '25', '"410', '340"', '"40', '000"', '1.9', '41', '88%', '0.13%']
# ['92', 'Honduras', '"9', '904', '607"', '1.63%', '"158', '490"', '89', '"111', '890"', '"-6', '800"', '2.5', '24', '57%', '0.13%']
# ['93', 'United Arab Emirates', '"9', '890', '402"', '1.23%', '"119', '873"', '118', '"83', '600"', '"40', '000"', '1.4', '33', '86%', '0.13%']
# ['94', 'Hungary', '"9', '660', '351"', '-0.25%', '"-24', '328"', '107', '"90', '530"', '"6', '000"', '1.5', '43', '72%', '0.12%']
# ['95', 'Tajikistan', '"9', '537', '645"', '2.32%', '"216', '627"', '68', '"139', '960"', '"-20', '000"', '3.6', '22', '27%', '0.12%']
# ['96', 'Belarus', '"9', '449', '323"', '-0.03%', '"-3', '088"', '47', '"202', '910"', '"8', '730"', '1.7', '40', '79%', '0.12%']
# ['97', 'Austria', '"9', '006', '398"', '0.57%', '"51', '296"', '109', '"82', '409"', '"65', '000"', '1.5', '43', '57%', '0.12%']
# ['98', 'Papua New Guinea', '"8', '947', '024"', '1.95%', '"170', '915"', '20', '"452', '860"', '-800', '3.6', '22', '13%', '0.11%']
# ['99', 'Serbia', '"8', '737', '371"', '-0.40%', '"-34', '864"', '100', '"87', '460"', '"4', '000"', '1.5', '42', '56%', '0.11%']
# ['100', 'Israel', '"8', '655', '535"', '1.60%', '"136', '158"', '400', '"21', '640"', '"10', '000"', '3', '30', '93%', '0.11%']
# ['101', 'Switzerland', '"8', '654', '622"', '0.74%', '"63', '257"', '219', '"39', '516"', '"52', '000"', '1.5', '43', '74%', '0.11%']
# ['102', 'Togo', '"8', '278', '724"', '2.43%', '"196', '358"', '152', '"54', '390"', '"-2', '000"', '4.4', '19', '43%', '0.11%']
# ['103', 'Sierra Leone', '"7', '976', '983"', '2.10%', '"163', '768"', '111', '"72', '180"', '"-4', '200"', '4.3', '19', '43%', '0.10%']
# ['104', 'Hong Kong', '"7', '496', '981"', '0.82%', '"60', '827"', '"7', '140"', '"1', '050"', '"29', '308"', '1.3', '45', 'N.A.', '0.10%']
# ['105', 'Laos', '"7', '275', '560"', '1.48%', '"106', '105"', '32', '"230', '800"', '"-14', '704"', '2.7', '24', '36%', '0.09%']
# ['106', 'Paraguay', '"7', '132', '538"', '1.25%', '"87', '902"', '18', '"397', '300"', '"-16', '556"', '2.4', '26', '62%', '0.09%']
# ['107', 'Bulgaria', '"6', '948', '445"', '-0.74%', '"-51', '674"', '64', '"108', '560"', '"-4', '800"', '1.6', '45', '76%', '0.09%']
# ['108', 'Libya', '"6', '871', '292"', '1.38%', '"93', '840"', '4', '"1', '759', '540"', '"-1', '999"', '2.3', '29', '78%', '0.09%']
# ['109', 'Lebanon', '"6', '825', '445"', '-0.44%', '"-30', '268"', '667', '"10', '230"', '"-30', '012"', '2.1', '30', '78%', '0.09%']
# ['110', 'Nicaragua', '"6', '624', '554"', '1.21%', '"79', '052"', '55', '"120', '340"', '"-21', '272"', '2.4', '26', '57%', '0.08%']
# ['111', 'Kyrgyzstan', '"6', '524', '195"', '1.69%', '"108', '345"', '34', '"191', '800"', '"-4', '000"', '3', '26', '36%', '0.08%']
# ['112', 'El Salvador', '"6', '486', '205"', '0.51%', '"32', '652"', '313', '"20', '720"', '"-40', '539"', '2.1', '28', '73%', '0.08%']
# ['113', 'Turkmenistan', '"6', '031', '200"', '1.50%', '"89', '111"', '13', '"469', '930"', '"-5', '000"', '2.8', '27', '53%', '0.08%']
# ['114', 'Singapore', '"5', '850', '342"', '0.79%', '"46', '005"', '"8', '358"', '700', '"27', '028"', '1.2', '42', 'N.A.', '0.08%']
# ['115', 'Denmark', '"5', '792', '202"', '0.35%', '"20', '326"', '137', '"42', '430"', '"15', '200"', '1.8', '42', '88%', '0.07%']
# ['116', 'Finland', '"5', '540', '720"', '0.15%', '"8', '564"', '18', '"303', '890"', '"14', '000"', '1.5', '43', '86%', '0.07%']
# ['117', 'Congo', '"5', '518', '087"', '2.56%', '"137', '579"', '16', '"341', '500"', '"-4', '000"', '4.5', '19', '70%', '0.07%']
# ['118', 'Slovakia', '"5', '459', '642"', '0.05%', '"2', '629"', '114', '"48', '088"', '"1', '485"', '1.5', '41', '54%', '0.07%']
# ['119', 'Norway', '"5', '421', '241"', '0.79%', '"42', '384"', '15', '"365', '268"', '"28', '000"', '1.7', '40', '83%', '0.07%']
# ['120', 'Oman', '"5', '106', '626"', '2.65%', '"131', '640"', '16', '"309', '500"', '"87', '400"', '2.9', '31', '87%', '0.07%']
# ['121', 'State of Palestine', '"5', '101', '414"', '2.41%', '"119', '994"', '847', '"6', '020"', '"-10', '563"', '3.7', '21', '80%', '0.07%']
# ['122', 'Costa Rica', '"5', '094', '118"', '0.92%', '"46', '557"', '100', '"51', '060"', '"4', '200"', '1.8', '33', '80%', '0.07%']
# ['123', 'Liberia', '"5', '057', '681"', '2.44%', '"120', '307"', '53', '"96', '320"', '"-5', '000"', '4.4', '19', '53%', '0.06%']
# ['124', 'Ireland', '"4', '937', '786"', '1.13%', '"55', '291"', '72', '"68', '890"', '"23', '604"', '1.8', '38', '63%', '0.06%']
# ['125', 'Central African Republic', '"4', '829', '767"', '1.78%', '"84', '582"', '8', '"622', '980"', '"-40', '000"', '4.8', '18', '43%', '0.06%']
# ['126', 'New Zealand', '"4', '822', '233"', '0.82%', '"39', '170"', '18', '"263', '310"', '"14', '881"', '1.9', '38', '87%', '0.06%']
# ['127', 'Mauritania', '"4', '649', '658"', '2.74%', '"123', '962"', '5', '"1', '030', '700"', '"5', '000"', '4.6', '20', '57%', '0.06%']
# ['128', 'Panama', '"4', '314', '767"', '1.61%', '"68', '328"', '58', '"74', '340"', '"11', '200"', '2.5', '30', '68%', '0.06%']
# ['129', 'Kuwait', '"4', '270', '571"', '1.51%', '"63', '488"', '240', '"17', '820"', '"39', '520"', '2.1', '37', 'N.A.', '0.05%']
# ['130', 'Croatia', '"4', '105', '267"', '-0.61%', '"-25', '037"', '73', '"55', '960"', '"-8', '001"', '1.4', '44', '58%', '0.05%']
# ['131', 'Moldova', '"4', '033', '963"', '-0.23%', '"-9', '300"', '123', '"32', '850"', '"-1', '387"', '1.3', '38', '43%', '0.05%']
# ['132', 'Georgia', '"3', '989', '167"', '-0.19%', '"-7', '598"', '57', '"69', '490"', '"-10', '000"', '2.1', '38', '58%', '0.05%']
# ['133', 'Eritrea', '"3', '546', '421"', '1.41%', '"49', '304"', '35', '"101', '000"', '"-39', '858"', '4.1', '19', '63%', '0.05%']
# ['134', 'Uruguay', '"3', '473', '730"', '0.35%', '"11', '996"', '20', '"175', '020"', '"-3', '000"', '2', '36', '96%', '0.04%']
# ['135', 'Bosnia and Herzegovina', '"3', '280', '819"', '-0.61%', '"-20', '181"', '64', '"51', '000"', '"-21', '585"', '1.3', '43', '52%', '0.04%']
# ['136', 'Mongolia', '"3', '278', '290"', '1.65%', '"53', '123"', '2', '"1', '553', '560"', '-852', '2.9', '28', '67%', '0.04%']
# ['137', 'Armenia', '"2', '963', '243"', '0.19%', '"5', '512"', '104', '"28', '470"', '"-4', '998"', '1.8', '35', '63%', '0.04%']
# ['138', 'Jamaica', '"2', '961', '167"', '0.44%', '"12', '888"', '273', '"10', '830"', '"-11', '332"', '2', '31', '55%', '0.04%']
# ['139', 'Qatar', '"2', '881', '053"', '1.73%', '"48', '986"', '248', '"11', '610"', '"40', '000"', '1.9', '32', '96%', '0.04%']
# ['140', 'Albania', '"2', '877', '797"', '-0.11%', '"-3', '120"', '105', '"27', '400"', '"-14', '000"', '1.6', '36', '63%', '0.04%']
# ['141', 'Puerto Rico', '"2', '860', '853"', '-2.47%', '"-72', '555"', '323', '"8', '870"', '"-97', '986"', '1.2', '44', 'N.A.', '0.04%']
# ['142', 'Lithuania', '"2', '722', '289"', '-1.35%', '"-37', '338"', '43', '"62', '674"', '"-32', '780"', '1.7', '45', '71%', '0.03%']
# ['143', 'Namibia', '"2', '540', '905"', '1.86%', '"46', '375"', '3', '"823', '290"', '"-4', '806"', '3.4', '22', '55%', '0.03%']
# ['144', 'Gambia', '"2', '416', '668"', '2.94%', '"68', '962"', '239', '"10', '120"', '"-3', '087"', '5.3', '18', '59%', '0.03%']
# ['145', 'Botswana', '"2', '351', '627"', '2.08%', '"47', '930"', '4', '"566', '730"', '"3', '000"', '2.9', '24', '73%', '0.03%']
# ['146', 'Gabon', '"2', '225', '734"', '2.45%', '"53', '155"', '9', '"257', '670"', '"3', '260"', '4', '23', '87%', '0.03%']
# ['147', 'Lesotho', '"2', '142', '249"', '0.80%', '"16', '981"', '71', '"30', '360"', '"-10', '047"', '3.2', '24', '31%', '0.03%']
# ['148', 'North Macedonia', '"2', '083', '374"', '0.00%', '-85', '83', '"25', '220"', '"-1', '000"', '1.5', '39', '59%', '0.03%']
# ['149', 'Slovenia', '"2', '078', '938"', '0.01%', '284', '103', '"20', '140"', '"2', '000"', '1.6', '45', '55%', '0.03%']
# ['150', 'Guinea-Bissau', '"1', '968', '001"', '2.45%', '"47', '079"', '70', '"28', '120"', '"-1', '399"', '4.5', '19', '45%', '0.03%']
# ['151', 'Latvia', '"1', '886', '198"', '-1.08%', '"-20', '545"', '30', '"62', '200"', '"-14', '837"', '1.7', '44', '69%', '0.02%']
# ['152', 'Bahrain', '"1', '701', '575"', '3.68%', '"60', '403"', '"2', '239"', '760', '"47', '800"', '2', '32', '89%', '0.02%']
# ['153', 'Equatorial Guinea', '"1', '402', '985"', '3.47%', '"46', '999"', '50', '"28', '050"', '"16', '000"', '4.6', '22', '73%', '0.02%']
# ['154', 'Trinidad and Tobago', '"1', '399', '488"', '0.32%', '"4', '515"', '273', '"5', '130"', '-800', '1.7', '36', '52%', '0.02%']
# ['155', 'Estonia', '"1', '326', '535"', '0.07%', '887', '31', '"42', '390"', '"3', '911"', '1.6', '42', '68%', '0.02%']
# ['156', 'Timor-Leste', '"1', '318', '445"', '1.96%', '"25', '326"', '89', '"14', '870"', '"-5', '385"', '4.1', '21', '33%', '0.02%']
# ['157', 'Mauritius', '"1', '271', '768"', '0.17%', '"2', '100"', '626', '"2', '030"', '0', '1.4', '37', '41%', '0.02%']
# ['158', 'Cyprus', '"1', '207', '359"', '0.73%', '"8', '784"', '131', '"9', '240"', '"5', '000"', '1.3', '37', '67%', '0.02%']
# ['159', 'Eswatini', '"1', '160', '164"', '1.05%', '"12', '034"', '67', '"17', '200"', '"-8', '353"', '3', '21', '30%', '0.01%']
# ['160', 'Djibouti', '"988', '000"', '1.48%', '"14', '440"', '43', '"23', '180"', '900', '2.8', '27', '79%', '0.01%']
# ['161', 'Fiji', '"896', '445"', '0.73%', '"6', '492"', '49', '"18', '270"', '"-6', '202"', '2.8', '28', '59%', '0.01%']
# ['162', 'Réunion', '"895', '312"', '0.72%', '"6', '385"', '358', '"2', '500"', '"-1', '256"', '2.3', '36', '100%', '0.01%']
# ['163', 'Comoros', '"869', '601"', '2.20%', '"18', '715"', '467', '"1', '861"', '"-2', '000"', '4.2', '20', '29%', '0.01%']
# ['164', 'Guyana', '"786', '552"', '0.48%', '"3', '786"', '4', '"196', '850"', '"-6', '000"', '2.5', '27', '27%', '0.01%']
# ['165', 'Bhutan', '"771', '608"', '1.12%', '"8', '516"', '20', '"38', '117"', '320', '2', '28', '46%', '0.01%']
# ['166', 'Solomon Islands', '"686', '884"', '2.55%', '"17', '061"', '25', '"27', '990"', '"-1', '600"', '4.4', '20', '23%', '0.01%']
# ['167', 'Macao', '"649', '335"', '1.39%', '"8', '890"', '"21', '645"', '30', '"5', '000"', '1.2', '39', 'N.A.', '0.01%']
# ['168', 'Montenegro', '"628', '066"', '0.01%', '79', '47', '"13', '450"', '-480', '1.8', '39', '68%', '0.01%']
# ['169', 'Luxembourg', '"625', '978"', '1.66%', '"10', '249"', '242', '"2', '590"', '"9', '741"', '1.5', '40', '88%', '0.01%']
# ['170', 'Western Sahara', '"597', '339"', '2.55%', '"14', '876"', '2', '"266', '000"', '"5', '582"', '2.4', '28', '87%', '0.01%']
# ['171', 'Suriname', '"586', '632"', '0.90%', '"5', '260"', '4', '"156', '000"', '"-1', '000"', '2.4', '29', '65%', '0.01%']
# ['172', 'Cabo Verde', '"555', '987"', '1.10%', '"6', '052"', '138', '"4', '030"', '"-1', '342"', '2.3', '28', '68%', '0.01%']
# ['173', 'Micronesia', '"548', '914"', '1.00%', '"5', '428"', '784', '700', '"-2', '957"', '2.9', '27', '68%', '0.01%']
# ['174', 'Maldives', '"540', '544"', '1.81%', '"9', '591"', '"1', '802"', '300', '"11', '370"', '1.9', '30', '35%', '0.01%']
# ['175', 'Malta', '"441', '543"', '0.27%', '"1', '171"', '"1', '380"', '320', '900', '1.5', '43', '93%', '0.01%']
# ['176', 'Brunei', '"437', '479"', '0.97%', '"4', '194"', '83', '"5', '270"', '0', '1.8', '32', '80%', '0.01%']
# ['177', 'Guadeloupe', '"400', '124"', '0.02%', '68', '237', '"1', '690"', '"-1', '440"', '2.2', '44', 'N.A.', '0.01%']
# ['178', 'Belize', '"397', '628"', '1.86%', '"7', '275"', '17', '"22', '810"', '"1', '200"', '2.3', '25', '46%', '0.01%']
# ['179', 'Bahamas', '"393', '244"', '0.97%', '"3', '762"', '39', '"10', '010"', '"1', '000"', '1.8', '32', '86%', '0.01%']
# ['180', 'Martinique', '"375', '265"', '-0.08%', '-289', '354', '"1', '060"', '-960', '1.9', '47', '92%', '0.00%']
# ['181', 'Iceland', '"341', '243"', '0.65%', '"2', '212"', '3', '"100', '250"', '380', '1.8', '37', '94%', '0.00%']
# ['182', 'Vanuatu', '"307', '145"', '2.42%', '"7', '263"', '25', '"12', '190"', '120', '3.8', '21', '24%', '0.00%']
# ['183', 'French Guiana', '"298', '682"', '2.70%', '"7', '850"', '4', '"82', '200"', '"1', '200"', '3.4', '25', '87%', '0.00%']
# ['184', 'Barbados', '"287', '375"', '0.12%', '350', '668', '430', '-79', '1.6', '40', '31%', '0.00%']
# ['185', 'New Caledonia', '"285', '498"', '0.97%', '"2', '748"', '16', '"18', '280"', '502', '2', '34', '72%', '0.00%']
# ['186', 'French Polynesia', '"280', '908"', '0.58%', '"1', '621"', '77', '"3', '660"', '"-1', '000"', '2', '34', '64%', '0.00%']
# ['187', 'Mayotte', '"272', '815"', '2.50%', '"6', '665"', '728', '375', '0', '3.7', '20', '46%', '0.00%']
# ['188', 'Sao Tome & Principe', '"219', '159"', '1.91%', '"4', '103"', '228', '960', '"-1', '680"', '4.4', '19', '74%', '0.00%']
# ['189', 'Samoa', '"198', '414"', '0.67%', '"1', '317"', '70', '"2', '830"', '"-2', '803"', '3.9', '22', '18%', '0.00%']
# ['190', 'Saint Lucia', '"183', '627"', '0.46%', '837', '301', '610', '0', '1.4', '34', '19%', '0.00%']
# ['191', 'Channel Islands', '"173', '863"', '0.93%', '"1', '604"', '915', '190', '"1', '351"', '1.5', '43', '30%', '0.00%']
# ['192', 'Guam', '"168', '775"', '0.89%', '"1', '481"', '313', '540', '-506', '2.3', '31', '95%', '0.00%']
# ['193', 'Curaçao', '"164', '093"', '0.41%', '669', '370', '444', '515', '1.8', '42', '89%', '0.00%']
# ['194', 'Kiribati', '"119', '449"', '1.57%', '"1', '843"', '147', '810', '-800', '3.6', '23', '57%', '0.00%']
# ['195', 'Grenada', '"112', '523"', '0.46%', '520', '331', '340', '-200', '2.1', '32', '35%', '0.00%']
# ['196', 'St. Vincent & Grenadines', '"110', '940"', '0.32%', '351', '284', '390', '-200', '1.9', '33', '53%', '0.00%']
# ['197', 'Aruba', '"106', '766"', '0.43%', '452', '593', '180', '201', '1.9', '41', '44%', '0.00%']
# ['198', 'Tonga', '"105', '695"', '1.15%', '"1', '201"', '147', '720', '-800', '3.6', '22', '24%', '0.00%']
# ['199', 'U.S. Virgin Islands', '"104', '425"', '-0.15%', '-153', '298', '350', '-451', '2', '43', '96%', '0.00%']
# ['200', 'Seychelles', '"98', '347"', '0.62%', '608', '214', '460', '-200', '2.5', '34', '56%', '0.00%']
# ['201', 'Antigua and Barbuda', '"97', '929"', '0.84%', '811', '223', '440', '0', '2', '34', '26%', '0.00%']
# ['202', 'Isle of Man', '"85', '033"', '0.53%', '449', '149', '570', '', 'N.A.', 'N.A.', '53%', '0.00%']
# ['203', 'Andorra', '"77', '265"', '0.16%', '123', '164', '470', '', 'N.A.', 'N.A.', '88%', '0.00%']
# ['204', 'Dominica', '"71', '986"', '0.25%', '178', '96', '750', '', 'N.A.', 'N.A.', '74%', '0.00%']
# ['205', 'Cayman Islands', '"65', '722"', '1.19%', '774', '274', '240', '', 'N.A.', 'N.A.', '97%', '0.00%']
# ['206', 'Bermuda', '"62', '278"', '-0.36%', '-228', '"1', '246"', '50', '', 'N.A.', 'N.A.', '97%', '0.00%']
# ['207', 'Marshall Islands', '"59', '190"', '0.68%', '399', '329', '180', '', 'N.A.', 'N.A.', '70%', '0.00%']
# ['208', 'Northern Mariana Islands', '"57', '559"', '0.60%', '343', '125', '460', '', 'N.A.', 'N.A.', '88%', '0.00%']
# ['209', 'Greenland', '"56', '770"', '0.17%', '98', '0', '"410', '450"', '', 'N.A.', 'N.A.', '87%', '0.00%']
# ['210', 'American Samoa', '"55', '191"', '-0.22%', '-121', '276', '200', '', 'N.A.', 'N.A.', '88%', '0.00%']
# ['211', 'Saint Kitts & Nevis', '"53', '199"', '0.71%', '376', '205', '260', '', 'N.A.', 'N.A.', '33%', '0.00%']
# ['212', 'Faeroe Islands', '"48', '863"', '0.38%', '185', '35', '"1', '396"', '', 'N.A.', 'N.A.', '43%', '0.00%']
# ['213', 'Sint Maarten', '"42', '876"', '1.15%', '488', '"1', '261"', '34', '', 'N.A.', 'N.A.', '96%', '0.00%']
# ['214', 'Monaco', '"39', '242"', '0.71%', '278', '"26', '337"', '1', '', 'N.A.', 'N.A.', 'N.A.', '0.00%']
# ['215', 'Turks and Caicos', '"38', '717"', '1.38%', '526', '41', '950', '', 'N.A.', 'N.A.', '89%', '0.00%']
# ['216', 'Saint Martin', '"38', '666"', '1.75%', '664', '730', '53', '', 'N.A.', 'N.A.', '0%', '0.00%']
# ['217', 'Liechtenstein', '"38', '128"', '0.29%', '109', '238', '160', '', 'N.A.', 'N.A.', '15%', '0.00%']
# ['218', 'San Marino', '"33', '931"', '0.21%', '71', '566', '60', '', 'N.A.', 'N.A.', '97%', '0.00%']
# ['219', 'Gibraltar', '"33', '691"', '-0.03%', '-10', '"3', '369"', '10', '', 'N.A.', 'N.A.', 'N.A.', '0.00%']
# ['220', 'British Virgin Islands', '"30', '231"', '0.67%', '201', '202', '150', '', 'N.A.', 'N.A.', '52%', '0.00%']
# ['221', 'Caribbean Netherlands', '"26', '223"', '0.94%', '244', '80', '328', '', 'N.A.', 'N.A.', '75%', '0.00%']
# ['222', 'Palau', '"18', '094"', '0.48%', '86', '39', '460', '', 'N.A.', 'N.A.', 'N.A.', '0.00%']
# ['223', 'Cook Islands', '"17', '564"', '0.09%', '16', '73', '240', '', 'N.A.', 'N.A.', '75%', '0.00%']
# ['224', 'Anguilla', '"15', '003"', '0.90%', '134', '167', '90', '', 'N.A.', 'N.A.', 'N.A.', '0.00%']
# ['225', 'Tuvalu', '"11', '792"', '1.25%', '146', '393', '30', '', 'N.A.', 'N.A.', '62%', '0.00%']
# ['226', 'Wallis & Futuna', '"11', '239"', '-1.69%', '-193', '80', '140', '', 'N.A.', 'N.A.', '0%', '0.00%']
# ['227', 'Nauru', '"10', '824"', '0.63%', '68', '541', '20', '', 'N.A.', 'N.A.', 'N.A.', '0.00%']
# ['228', 'Saint Barthelemy', '"9', '877"', '0.30%', '30', '470', '21', '', 'N.A.', 'N.A.', '0%', '0.00%']
# ['229', 'Saint Helena', '"6', '077"', '0.30%', '18', '16', '390', '', 'N.A.', 'N.A.', '27%', '0.00%']
# ['230', 'Saint Pierre & Miquelon', '"5', '794"', '-0.48%', '-28', '25', '230', '', 'N.A.', 'N.A.', '100%', '0.00%']
# ['231', 'Montserrat', '"4', '992"', '0.06%', '3', '50', '100', '', 'N.A.', 'N.A.', '10%', '0.00%']
# ['232', 'Falkland Islands', '"3', '480"', '3.05%', '103', '0', '"12', '170"', '', 'N.A.', 'N.A.', '66%', '0.00%']
# ['233', 'Niue', '"1', '626"', '0.68%', '11', '6', '260', '', 'N.A.', 'N.A.', '46%', '0.00%']
# ['234', 'Tokelau', '"1', '357"', '1.27%', '17', '136', '10', '', 'N.A.', 'N.A.', '0%', '0.00%']
# ['235', 'Holy See', '801', '0.25%', '2', '"2', '003"', '0', '', 'N.A.', 'N.A.', 'N.A.', '0.00%']

# %% [markdown]
# ## Proceso completo
#
# Hemos visto parte del proceso ETL, pero en realidad lo que tenemos que hacer es leer un fichero completo y transformar todas las líneas (no sólo una) para después guardarlas en un nuevo fichero.
#
# Veamos ésto paso a paso. Para ello vamos a usar el siguiente dataset.
#
# ######  https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset
#
#
# ### El Algoritmo que vamos a seguir:
# - PASO 1: Transformar 1 línea
# - PASO 2: Subir CSV a la nube y hacer el open() leyendo cada línea en un for
# - PASO 3: Conectar transformación de PASO 1 en el FOR del Paso 2
# - PASO 4: Guardar el fichero finalmente (Fichero Destino)

# %% [markdown]
# ### Paso 1
#
# Vamos a hacer lo que ya conoces.
#
# > **Ejercicio**: Esta vez no tienes que completar código, simplemente intenta traducir lo que se hace y qué campos se cogen.

# %%
''',track_id,artists,album_name,track_name,popularity,duration_ms,explicit,danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,time_signature,track_genre'''

lineaOrigen = '0,5SuOikwiRyPMVoIQDJUgSV,Gen Hoshino,Comedy,Comedy,73,230666,False,0.676,0.461,1,-6.746,0,0.143,0.0322,1.01e-06,0.358,0.715,128,4,acousti'
print(lineaOrigen)  

lineaOrigen = lineaOrigen.split(',')

numArtistas = 1
if (len( lineaOrigen[2].split(';') ) > 0 ):
  numArtistas = len( lineaOrigen[2].split(';') ) 

explicito = lineaOrigen[7]
if(explicito[0] == 'T'):
    explicito = -1
elif(explicito[0] == 'F'):
    explicito = 1
else:
  explicito = 0

tempo = float(lineaOrigen[-3])
if(tempo == 128):
  tempo = 10
elif(tempo > 120):
  tempo = 1
elif(tempo <= 120 and tempo > 100):
  tempo = 0
elif(tempo <= 100):
  tempo = -1

popularidad = int(lineaOrigen[5]) / 100

duracion = int(lineaOrigen[6]) / (60 * 1000) 

polaridad = (float(lineaOrigen[8]) + float(lineaOrigen[11]) + float(lineaOrigen[13]) )/3 

genero = lineaOrigen[-1]

lineaDestino = [numArtistas, popularidad, duracion, explicito, polaridad, tempo, genero]
print(lineaDestino)
# Out:
# 0,5SuOikwiRyPMVoIQDJUgSV,Gen Hoshino,Comedy,Comedy,73,230666,False,0.676,0.461,1,-6.746,0,0.143,0.0322,1.01e-06,0.358,0.715,128,4,acousti
# [1, 0.73, 3.8444333333333334, 1, -1.975666666666667, 10, 'acousti']

# %% [markdown]
# ### Paso 2
# Fijémonos en la Documentación Oficial de la Librería CSV (https://docs.python.org/3/library/csv.html) para este paso.
#
# PD: Como son demasiadas líneas y tarda un rato, puedes parar tú mismo la ejecución cuando veas oportuno.

# %%
import csv
with open('dataset.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',') #delimiter = Separadoe
    next(spamreader) #Tema cursores, ficheros y cabecera CSV...
    for lineaOrigen in spamreader:
        print('Linea Origen:', lineaOrigen)
# Out:
# Streaming output truncated to the last 5000 lines.
# Linea Origen: ['1713', '18OzYEBhFuusiRbvkhf6Zl', 'Menahan Street Band', 'Make the Road By Walking', 'Make the Road By Walking', '51', '183213', 'False', '0.615', '0.76', '10', '-8.393', '0', '0.0317', '0.0186', '0.053', '0.0825', '0.902', '90.847', '4', 'afrobeat']
# Linea Origen: ['1714', '5gDTvqxpIAAAXLIUPYKsTM', 'Limoblaze', 'Blind', 'Eledumare', '17', '200412', 'False', '0.709', '0.854', '11', '-5.016', '0', '0.247', '0.492', '0.0', '0.11', '0.816', '103.018', '4', 'afrobeat']
# Linea Origen: ['1715', '4K42ppHKqdf3798vUg1ult', 'Foli Griô Orquestra;Carlos Malta;Dofono de Omulu;Ekedi Nicinha', 'AJO', 'Awo', '17', '494532', 'False', '0.594', '0.716', '11', '-6.656', '0', '0.0472', '0.217', '0.0533', '0.0539', '0.931', '133.407', '4', 'afrobeat']
# Linea Origen: ['1716', '1GXMf1AsiM1cdMMCtsffa1', 'Orgone', 'The Killion Floor', 'Do Your Thing', '18', '241200', 'False', '0.586', '0.702', '4', '-6.324', '0', '0.0482', '0.553', '0.00312', '0.0943', '0.69', '143.434', '4', 'afrobeat']
# Linea Origen: ['1717', '0bIcfdH8VWCXcR0KNjDRF2', 'Chief Checker', 'Nigeria 70 - Lagos Jump', 'Africa Irie', '17', '342013', 'False', '0.745', '0.587', '9', '-8.101', '0', '0.163', '0.0329', '0.273', '0.0922', '0.86', '131.977', '4', 'afrobeat']
# Linea Origen: ['1718', '60xdLXU4rTPmPTPrfelJDf', 'Mandrill', 'Mandrill Is', 'I Refuse To Smile', '18', '247760', 'False', '0.544', '0.697', '4', '-7.36', '0', '0.0323', '0.205', '0.000121', '0.193', '0.654', '87.557', '4', 'afrobeat']
# Linea Origen: ['1719', '78DMTISae46jqQmAAYHjJo', 'Zé Bigode Orquestra', 'Clube da Fumaça', 'Vai C Bom', '18', '193887', 'False', '0.615', '0.874', '7', '-6.186', '0', '0.0531', '0.176', '1.66e-05', '0.0536', '0.389', '189.944', '4', 'afrobeat']
# Linea Origen: ['1720', '0SOmYqBeGm7Hrd0lXseV2e', 'Criolo', 'Ainda Há Tempo', 'Ainda Há Tempo', '18', '318360', 'False', '0.58', '0.8', '6', '-7.528', '1', '0.345', '0.281', '0.0', '0.0708', '0.483', '81.303', '4', 'afrobeat']
# Linea Origen: ['1721', '2Szjsv5SLiGyCPAraUnNvk', 'Gyedu-Blay Ambolley', 'Ketan', 'Ketan', '17', '357074', 'False', '0.644', '0.823', '10', '-6.564', '1', '0.0518', '0.145', '0.194', '0.12', '0.508', '104.967', '4', 'afrobeat']
# Linea Origen: ['1786', '3rllhj4WKYq3DG35DhCpRP', 'Juanafé;La Flor del Recuerdo', 'Parrilladas Vargas (Vol. II)', 'Mi Último Fracaso', '18', '265086', 'False', '0.457', '0.332', '0', '-10.365', '1', '0.0356', '0.791', '8.22e-06', '0.102', '0.305', '164.096', '3', 'afrobeat']
# Linea Origen: ['1787', '1udcRyPUJr8B8N7hAE1Sdm', 'Los Amigos Invisibles', 'Arepa 3000', 'Masturbation Session', '20', '293386', 'False', '0.843', '0.822', '5', '-6.455', '0', '0.0865', '0.0221', '0.0158', '0.182', '0.86', '117.971', '4', 'afrobeat']
# Linea Origen: ['1788', '1PphwDVGRYmR7tGMvdsfo5', 'The New Mastersounds', 'The Nashville Session', 'Burnt Back', '19', '224095', 'False', '0.537', '0.903', '9', '-6.951', '1', '0.0503', '0.452', '0.852', '0.126', '0.843', '111.801', '4', 'afrobeat']
# Linea Origen: ['1789', '6gaUC3ms3gCGggnfTdT2QL', 'BaianaSystem', 'BaianaSystem', 'Frevofoguete', '18', '206066', 'False', '0.482', '0.714', '4', '-8.796', '0', '0.0532', '0.0127', '0.903', '0.107', '0.656', '155.103', '4', 'afrobeat']
# Linea Origen: ['1790', '4HA6HwaRTzB0b2hlFV1Ncb', 'Zé Bigode Orquestra;Guinu', 'Clube da Fumaça', 'Alfazema Y Guiné (feat. Guinu)', '17', '118388', 'False', '0.875', '0.761', '6', '-5.556', '1', '0.0576', '0.162', '0.0', '0.256', '0.912', '129.911', '4', 'afrobeat']
# Linea Origen: ['1791', '1m25j7wivTQQMZebdPJyO8', 'BaianaSystem;Thiago França', 'ATO 3: América do Sol', 'Reza Frevo', '18', '96766', 'False', '0.451', '0.983', '2', '-7.436', '0', '0.347', '0.0909', '0.982', '0.107', '0.378', '161.108', '4', 'afrobeat']
# Linea Origen: ['1792', '5ZSnUYUX2cuOpsSbVo3Wot', 'Los Amigos Invisibles', 'Live En Una Noche Tan Linda Como Esta Vol 1', 'Yo No Se', '20', '132284', 'False', '0.56', '0.822', '0', '-9.234', '1', '0.032', '0.256', '0.712', '0.561', '0.962', '131.774', '4', 'afrobeat']
# Linea Origen: ['1793', '4BPfhlDv2iYWwpFgaBf4yO', 'Calle 13', 'Los De Atrás Vienen Conmigo', 'Electro Movimiento', '19', '196986', 'False', '0.803', '0.86', '8', '-6.522', '1', '0.135', '0.0782', '4.45e-05', '0.128', '0.534', '109.966', '4', 'afrobeat']
# Linea Origen: ['1794', '6v3BRYhBazEhyhm6FeKXL2', 'Newen Afrobeat', 'Curiche', 'Come y Calla', '17', '540346', 'False', '0.795', '0.857', '11', '-7.772', '0', '0.0492', '0.526', '0.457', '0.0968', '0.845', '97.01', '4', 'afrobeat']
# Linea Origen: ['1795', '6cLtKtakegCY6n7iepcLYJ', 'Ebo Taylor;Uhuru-Yenzu', 'Conflict', 'Love and Death', '18', '499733', 'False', '0.804', '0.92', '0', '-7.478', '1', '0.0563', '0.158', '0.0797', '0.0743', '0.811', '108.979', '4', 'afrobeat']
# Linea Origen: ['1796', '3C0K6ldyghoPafc1rde6qJ', 'Plastilina Mosh', 'Juan Manuel', 'Tiki Fiesta', '19', '187173', 'False', '0.768', '0.688', '10', '-9.079', '0', '0.0431', '0.103', '0.73', '0.113', '0.4', '125.112', '4', 'afrobeat']
# Linea Origen: ['1797', '5SdeTZrJw0QKJ2J7H1afi7', 'Metá Metá', 'MetaL MetaL', 'Man Feriman', '18', '460120', 'False', '0.475', '0.76', '8', '-6.128', '1', '0.0405', '0.276', '0.000137', '0.367', '0.359', '109.977', '4', 'afrobeat']
# Linea Origen: ['1798', '0dQwKBwUx7bPLjksSyHYYZ', 'Plastilina Mosh', 'Tasty + B Sides', 'Te Lo Juro Por Madonna (Si Omba Ta Gueno)', '19', '181026', 'False', '0.517', '0.966', '9', '-5.724', '0', '0.0568', '0.000439', '0.0864', '0.123', '0.711', '98.14', '4', 'afrobeat']
# Linea Origen: ['1799', '0MAjodNUjLlzRw9hd65QiS', 'Los Amigos Invisibles', 'The New Sound of the Venezuelan Gozadera', 'Mango Cool', '19', '174293', 'False', '0.527', '0.883', '0', '-6.799', '0', '0.0316', '0.0204', '0.755', '0.0913', '0.828', '155.135', '4', 'afrobeat']
# Linea Origen: ['1800', '0gGslfeZ5GjK19VcS82Sqa', 'Kutiman', 'Mix Tel Aviv', 'Mix Tel Aviv', '36', '277438', 'False', '0.751', '0.688', '0', '-8.023', '1', '0.0436', '0.102', '0.84', '0.0799', '0.403', '120.96', '4', 'afrobeat']
# Linea Origen: ['1801', '6TRYv8brfH12SfgV8lMraP', 'Akalé Wubé', 'Mata', 'Mata', '44', '230853', 'False', '0.569', '0.496', '4', '-11.423', '0', '0.0674', '0.393', '0.924', '0.11', '0.808', '82.822', '4', 'afrobeat']
# Linea Origen: ['1802', '2WcN7sgqqFNZMiMEeLvE3A', 'TB1', 'Thank You', 'Thank You', '39', '235826', 'False', '0.775', '0.808', '1', '-2.038', '0', '0.0465', '0.113', '0.0', '0.0628', '0.912', '115.011', '4', 'afrobeat']
# Linea Origen: ['1803', '5outtQyJ8AQxd4ykOyu8XV', 'Louis Pascal', 'Life of Grace', 'Life of Grace', '34', '205973', 'False', '0.59', '0.491', '0', '-9.304', '0', '0.233', '0.0128', '4.71e-05', '0.143', '0.253', '193.616', '4', 'afrobeat']
# Linea Origen: ['1804', '44kT6XsCkSGb9wNQ5qGXvg', 'Jungle Fire', 'Tropicoso', "Comencemos (Let's Start)", '44', '152600', 'False', '0.666', '0.903', '0', '-6.462', '1', '0.0456', '0.23', '0.616', '0.151', '0.913', '111.84', '4', 'afrobeat']
# Linea Origen: ['1805', '7EUnYSsHzHMgAg6pLmAYfx', 'Oneness Of Juju', "Breezin'", "Breezin'", '17', '329333', 'False', '0.616', '0.476', '11', '-11.388', '1', '0.0536', '0.687', '0.599', '0.0991', '0.862', '80.318', '4', 'afrobeat']
# Linea Origen: ['1806', '4I6a6PjNI9RGVt402sTeqh', 'Becca Folkes', 'In My Own Words', 'He Turned It', '17', '243408', 'False', '0.663', '0.872', '0', '-5.162', '1', '0.0692', '0.0221', '8.37e-05', '0.0806', '0.585', '97.0', '4', 'afrobeat']
# Linea Origen: ['1807', '4CuXyFGGXns7BvvYYCaWA0', 'Greyboy', 'Soul Mosaic', 'Omega', '19', '64693', 'False', '0.755', '0.876', '2', '-8.079', '1', '0.0729', '0.014', '0.826', '0.0641', '0.894', '108.383', '4', 'afrobeat']
# Linea Origen: ['1808', '174aZteQew30wcq8sPzlW6', 'Ikebe Shakedown', 'Stone by Stone', 'Rio Grande', '46', '230986', 'False', '0.445', '0.605', '11', '-7.509', '0', '0.0304', '0.25', '0.76', '0.321', '0.692', '162.588', '4', 'afrobeat']
# Linea Origen: ['1809', '3PBZeQmbywJVKdlRBzSg2C', 'The Shaolin Afronauts', 'The Fundamental Nature of Being, Part One', 'Abyssinian Suite, Pt. 4', '41', '292228', 'False', '0.526', '0.762', '11', '-12.783', '0', '0.0401', '0.0183', '0.511', '0.0664', '0.867', '110.086', '4', 'afrobeat']
# Linea Origen: ['1810', '3oZWXld4ObidTo8tShLNxZ', 'TJ Cream;Ozoro', 'Haven`t You Heard?', 'Haven`t You Heard?', '17', '189048', 'False', '0.865', '0.443', '6', '-11.879', '0', '0.414', '0.148', '0.0', '0.0609', '0.738', '160.001', '4', 'afrobeat']
# Linea Origen: ['1811', '6CtD4OlyP18mLPEhBotviY', 'Jaron Nurse', 'Uncommon', 'Uncommon Girl', '17', '144065', 'False', '0.908', '0.631', '4', '-9.078', '0', '0.0543', '0.128', '0.000897', '0.165', '0.819', '110.048', '4', 'afrobeat']
# Linea Origen: ['1812', '342MrQja9hV0VipxM0iuNr', 'Maga Bo;Mestre Camaleão', 'Quilombo do Futuro', 'É da Nossa Cor', '17', '195386', 'False', '0.668', '0.873', '3', '-3.887', '0', '0.0558', '0.422', '0.0', '0.355', '0.771', '116.968', '4', 'afrobeat']
# Linea Origen: ['1813', '1QGpYmCjN9Jp4MGXXKnlRt', 'Victor Rice', 'Drink', 'The Demander', '18', '138817', 'False', '0.678', '0.785', '11', '-8.721', '0', '0.044', '0.00941', '0.811', '0.17', '0.995', '141.557', '4', 'afrobeat']
# Linea Origen: ['1814', '6zeOuFLzYvFOfwedcmz7Nu', 'Sharyn', 'In Full Bloom', 'Burn Brighter / Like I do', '17', '204661', 'False', '0.855', '0.662', '6', '-7.488', '0', '0.0618', '0.33', '0.00172', '0.573', '0.487', '113.003', '4', 'afrobeat']
# Linea Origen: ['1815', '7HuER5q1a5dJ0uKrfGrMCj', 'Jlyricz', 'Searching', 'Searching', '16', '190714', 'False', '0.552', '0.424', '8', '-6.649', '1', '0.0722', '0.604', '0.0', '0.0849', '0.596', '204.128', '3', 'afrobeat']
# Linea Origen: ['1816', '0PXa2lGQZBqatc4iLCDF7Y', 'Speedometer', 'Our Kind of Movement', 'Funky Amigo', '17', '203414', 'False', '0.862', '0.673', '10', '-9.92', '0', '0.0492', '0.0568', '0.796', '0.0737', '0.823', '113.427', '4', 'afrobeat']
# Linea Origen: ['1848', '1qlSlUzvKDuBlETIxwmVJF', 'Antibalas', 'Talkatif', 'Talkatif', '16', '576133', 'False', '0.695', '0.942', '8', '-6.379', '1', '0.0774', '0.206', '0.301', '0.298', '0.851', '136.029', '4', 'afrobeat']
# Linea Origen: ['1849', '1401jEwuaQoh40lXA07jUg', 'Plastilina Mosh', 'Aquamosh', 'Savage Sucker Boy Featuring Pocahontas Freaky Groove', '19', '212893', 'False', '0.324', '0.826', '11', '-8.127', '0', '0.144', '0.00703', '7.85e-06', '0.682', '0.588', '128.375', '4', 'afrobeat']
# Linea Origen: ['1850', '7pW8qktBmU1SLIDeiVb8PP', 'Lara George', 'Higher', 'Dansaki', '39', '324572', 'False', '0.701', '0.94', '4', '-2.963', '1', '0.0497', '0.0619', '0.0288', '0.0962', '0.945', '139.497', '3', 'afrobeat']
# Linea Origen: ['1851', '2WaesAINqa4dKnLVu8JQKS', 'The Dynamics', 'Disco Reggae', 'Move on Up', '48', '292571', 'False', '0.845', '0.769', '11', '-7.838', '0', '0.036', '0.146', '0.355', '0.0917', '0.969', '145.985', '4', 'afrobeat']
# Linea Origen: ['1852', '1u5CtLtLmmY4KIe4k94XtA', 'El Michels Affair', 'Yeti Season (Deluxe Version)', 'Ala Vida', '42', '232357', 'False', '0.647', '0.386', '1', '-10.388', '1', '0.0571', '0.67', '0.906', '0.146', '0.491', '80.833', '4', 'afrobeat']
# Linea Origen: ['1853', '75lisbgzhfJdIt5YdPuAWP', 'Jorge Drexler', 'Frontera', 'La edad del cielo', '56', '219493', 'False', '0.668', '0.261', '7', '-13.003', '1', '0.0405', '0.588', '0.000391', '0.116', '0.282', '147.446', '4', 'afrobeat']
# Linea Origen: ['1854', '0BkI4Yoh4a6p3v0PXogsjs', 'Nomo', 'LP', 'Discontinued', '16', '482786', 'False', '0.394', '0.73', '5', '-8.74', '0', '0.0679', '0.0437', '0.854', '0.179', '0.795', '85.866', '4', 'afrobeat']
# Linea Origen: ['1855', '1Bx3trnFdCStyiV5PF0vkj', 'The Budos Band', 'The Budos Band', 'T.I.B.W.F.', '52', '160600', 'False', '0.674', '0.607', '1', '-7.76', '1', '0.057', '0.0124', '0.87', '0.147', '0.712', '77.845', '4', 'afrobeat']
# Linea Origen: ['1856', '7uiNQlqo95kRej5PcPrq4U', 'A Mose', 'Faraway', 'Faraway', '16', '171702', 'False', '0.701', '0.739', '3', '-5.209', '0', '0.0585', '0.0855', '0.00369', '0.0887', '0.247', '100.981', '4', 'afrobeat']
# Linea Origen: ['1857', '6MMXwZyjQhw6HaIwFGW0JI', 'Girma Bèyènè;Akalé Wubé', 'Mistakes on Purpose (Ethiopiques 30)', 'Enkèn Yèlélèbesh', '45', '238440', 'False', '0.74', '0.492', '5', '-8.72', '0', '0.0366', '0.589', '0.000796', '0.119', '0.893', '128.648', '4', 'afrobeat']
# Linea Origen: ['1858', '5ubvcUYndr5yA09c1OynaB', 'Buyepongo', 'Cantarito', 'Cantarito', '17', '324986', 'False', '0.571', '0.783', '4', '-7.893', '0', '0.0561', '0.317', '0.579', '0.131', '0.866', '121.39', '4', 'afrobeat']
# Linea Origen: ['1859', '5gXeGIJCGNycRlkoBIpBeJ', 'J Prince', 'Om3ga: Krng the Mixtape', 'Must Reach', '17', '184800', 'False', '0.808', '0.778', '6', '-4.791', '1', '0.0807', '0.198', '0.0', '0.101', '0.613', '100.009', '4', 'afrobeat']
# Linea Origen: ['1860', '6KKIxIWUL2dOn4CxmvY0H9', 'Calle 13', 'Residente o Visitante', 'El Avión Se Cae', '19', '257693', 'True', '0.759', '0.78', '0', '-8.007', '1', '0.0385', '0.0024', '0.0506', '0.321', '0.51', '125.05', '4', 'afrobeat']
# Linea Origen: ['1861', '77bHEazbuFqK3tTvoHFWQ3', 'Assagai', 'Assagai', 'Telephone Girl', '17', '214533', 'False', '0.604', '0.52', '1', '-12.658', '1', '0.08', '0.0758', '7.95e-05', '0.089', '0.966', '102.502', '4', 'afrobeat']
# Linea Origen: ['1862', '6yJUTxxr6IDc6A9nsQAoGy', 'Bacao Rhythm & Steel Band', 'Expansions', 'Represent', '17', '199398', 'False', '0.717', '0.513', '4', '-7.916', '0', '0.0337', '0.00956', '0.813', '0.112', '0.79', '92.968', '4', 'afrobeat']
# Linea Origen: ['1863', '34Qr17Bzt50nD101GsIsh8', 'Morbo y Mambo', 'Boa', 'Chori 95', '17', '251453', 'False', '0.472', '0.821', '7', '-6.471', '0', '0.0415', '0.000143', '0.792', '0.121', '0.519', '95.93', '4', 'afrobeat']
# Linea Origen: ['1864', '6mmyRIjtOmYDYxaFRDByfY', 'J Prince', 'Unlimited', 'Blood', '17', '216442', 'False', '0.85', '0.902', '9', '-5.441', '1', '0.257', '0.13', '1.73e-05', '0.0867', '0.836', '127.968', '4', 'afrobeat']
# Linea Origen: ['1865', '6Pwk5rWWIkBgwkl62lXjBp', 'Bacao Rhythm & Steel Band', '55', 'Tender Trap', '17', '213631', 'False', '0.69', '0.707', '0', '-3.826', '1', '0.0986', '0.16', '0.773', '0.0373', '0.746', '94.275', '4', 'afrobeat']
# Linea Origen: ['1866', '6DBqULxLjq66GX2dim7opR', 'Lack Of Afro', 'Press On', 'The Outsider', '49', '227346', 'False', '0.681', '0.838', '0', '-6.538', '1', '0.0797', '0.0874', '0.49', '0.348', '0.456', '112.608', '4', 'afrobeat']
# Linea Origen: ['1867', '04fpUM7YWaU5EQEohGpw4y', 'Voilaaa;Rama Traore', 'Voiciii', 'Tu Mens Devant Moi', '17', '247255', 'False', '0.817', '0.601', '7', '-11.881', '0', '0.0424', '0.0685', '0.00666', '0.0719', '0.847', '129.971', '4', 'afrobeat']
# Linea Origen: ['1868', '3i0diO0lN4p4tfvomLBKNP', 'Orgone', 'Sweet Feet', 'Sweet Feet', '18', '229633', 'False', '0.766', '0.722', '9', '-7.949', '0', '0.0549', '0.0335', '1.01e-05', '0.0791', '0.842', '122.369', '4', 'afrobeat']
# Linea Origen: ['1869', '3yw51GwjMWYYK9RkNfcHr9', 'Voilaaa;Lass;JKriv', 'Remixes', 'Ku La Foon - JKriv Remix', '16', '398280', 'False', '0.811', '0.598', '9', '-11.6', '0', '0.0634', '0.0561', '0.268', '0.0476', '0.86', '119.998', '4', 'afrobeat']
# Linea Origen: ['1870', '78U7dsruM76CzAnTSZ4npT', 'The Funkees', "Dancing Time: The Best of Eastern Nigeria's Afro Rock Exponents 1973-77", 'Akula Owu Onyeara', '39', '448914', 'False', '0.701', '0.702', '5', '-10.323', '0', '0.122', '0.525', '0.0486', '0.235', '0.885', '110.721', '4', 'afrobeat']
# Linea Origen: ['1871', '2J151Q4dYeMJ4y4scrmrjE', 'Los Pirañas', 'Historia natural', 'Puerta del sol', '16', '270090', 'False', '0.573', '0.856', '9', '-7.321', '0', '0.0392', '0.0736', '0.79', '0.0889', '0.929', '103.748', '4', 'afrobeat']
# Linea Origen: ['1872', '3mNtJ94LS5gTrclSCE9w9r', 'Ebo Taylor;Pat Thomas;Henrik Schwarz', 'Ene Nyame (Henrik Schwarz Blend)', "Eye Nyam Nam 'A' Mensuro - Henrik Schwarz Blend", '49', '563866', 'False', '0.761', '0.626', '5', '-12.634', '1', '0.0421', '0.0172', '0.634', '0.0879', '0.715', '124.024', '4', 'afrobeat']
# Linea Origen: ['1873', '4iJpsYr99D3Me2baq7kke9', 'Voilaaa;Pat Kalla', 'Voiciii', 'Faut Pas Dire Des Choses Comme Ça', '16', '275162', 'False', '0.738', '0.717', '6', '-13.001', '0', '0.391', '0.473', '1.39e-05', '0.21', '0.936', '134.668', '4', 'afrobeat']
# Linea Origen: ['1874', '0CDucx9lKxuCZplLXUz0iX', 'Buena Onda Reggae Club', 'Disco 2', 'Song for Rollins', '16', '219346', 'False', '0.841', '0.577', '0', '-7.544', '1', '0.0438', '0.238', '0.86', '0.0571', '0.843', '90.522', '4', 'afrobeat']
# Linea Origen: ['1875', '64hHlwJnvR9bOgSF5fYXjN', 'Timoneki', 'Timoneki', 'Donde Vas', '16', '271457', 'False', '0.564', '0.62', '7', '-7.976', '0', '0.0399', '0.0443', '0.0133', '0.0798', '0.487', '180.008', '4', 'afrobeat']
# Linea Origen: ['1876', '3yTF02CGqSPhca4sRk2rsw', 'The Daktaris', 'Soul Explosion', 'Upside Down', '16', '254920', 'False', '0.66', '0.807', '8', '-8.557', '0', '0.0531', '0.103', '0.662', '0.0688', '0.754', '113.893', '4', 'afrobeat']
# Linea Origen: ['1877', '7iX4C1EgJgtt5ocP5IRrMt', 'Brownout;Brown Sabbath;Alex Maas', 'Brownout Presents Brown Sabbath', 'Hand of Doom', '17', '463991', 'False', '0.379', '0.543', '0', '-8.478', '0', '0.0445', '0.0418', '0.000456', '0.109', '0.377', '146.446', '4', 'afrobeat']
# Linea Origen: ['1878', '6SRpVxkMTYbFSrTt9b7Kri', 'Nomade Orquestra;Edgar', 'Vox Populi, Vol. 1', 'Constante Mesmice', '16', '307493', 'False', '0.743', '0.643', '9', '-6.578', '0', '0.0434', '0.0462', '0.0775', '0.0694', '0.591', '128.029', '4', 'afrobeat']
# Linea Origen: ['1879', '1o4uajX6p6vKceoABwOwFP', 'Eddie Neblett', 'Elevation', 'Stepping Out', '17', '256391', 'False', '0.75', '0.705', '0', '-9.782', '1', '0.101', '0.198', '1.13e-06', '0.0862', '0.815', '119.898', '4', 'afrobeat']
 'Jorge Drexler', 'Sus primeras grabaciones 1992-1994 (La luz que sabe robar- Radar)', 'Radar', '18', '247586', 'False', '0.575', '0.771', '2', '-5.977', '1', '0.0395', '0.199', '0.00019', '0.0882', '0.696', '77.394', '4', 'afrobeat']
# Linea Origen: ['1892', '5Gmf4c1oRbQWQgZ8IB7PjU', "Jor'dan Armstrong", 'Blsd (Deluxe)', 'Reverse Effect', '17', '306372', 'False', '0.704', '0.486', '0', '-7.189', '0', '0.193', '0.36', '0.0', '0.0915', '0.415', '139.957', '4', 'afrobeat']
# Linea Origen: ['1893', '4dKAXHyIN8xkLTl5OIL9FN', 'Mulatu Astatke', 'Strut Afro-Beats', 'I Faram Gami I Faram - taken from Mulatu Steps Ahead', '17', '333400', 'False', '0.538', '0.593', '5', '-7.798', '0', '0.0388', '0.871', '0.878', '0.0596', '0.741', '86.564', '4', 'afrobeat']
# Linea Origen: ['1894', '1aAnuZ5RNefagXxjdmu4FI', 'Orgone', 'The Killion Floor', "It's What You Do", '17', '374853', 'False', '0.746', '0.811', '7', '-9.713', '0', '0.035', '0.157', '0.814', '0.0703', '0.914', '109.133', '4', 'afrobeat']
# Linea Origen: ['1895', '3BT0bKpJTZWYNuH5epKyOT', 'Samuca e a Selva', 'Ditados Populares Dançantes', 'Sincronia', '16', '212683', 'False', '0.791', '0.546', '11', '-8.81', '0', '0.0436', '0.034', '0.0211', '0.0464', '0.843', '100.064', '4', 'afrobeat']
# Linea Origen: ['1896', '7znoPLEFkoV16HW4qTSmXz', 'Mulatu Astatke;The Heliocentrics', 'Inspiration Information 3', 'Live From Tigre Lounge', '17', '174053', 'False', '0.656', '0.809', '11', '-8.175', '0', '0.073', '0.000881', '0.886', '0.105', '0.872', '132.404', '4', 'afrobeat']
# Linea Origen: ['1897', '3bgEz3NsFjabfbPN6DdOWN', 'Jorge Drexler', 'Sus primeras grabaciones 1992-1994 (La luz que sabe robar- Radar)', 'Bienvenida', '18', '297973', 'False', '0.789', '0.532', '0', '-8.555', '1', '0.0459', '0.54', '0.159', '0.107', '0.904', '112.732', '4', 'afrobeat']
# Linea Origen: ['1898', '00BHbc5GB5d35gsi8IsmZl', 'Jorge Drexler', 'Sus primeras grabaciones 1992-1994 (La luz que sabe robar- Radar)', 'No te creas', '17', '231893', 'False', '0.623', '0.803', '1', '-5.523', '0', '0.0327', '0.438', '4.58e-05', '0.165', '0.645', '126.61', '4', 'afrobeat']
# Linea Origen: ['1899', '5f7TqGqkS9heMOgduBRaKl', 'Los Amigos Invisibles', 'The New Sound of the Venezuelan Gozadera', 'Quiero Desintegrar a Tu Novio', '19', '206400', 'False', '0.778', '0.739', '10', '-5.56', '1', '0.0628', '0.294', '0.000187', '0.218', '0.923', '107.967', '4', 'afrobeat']
# Linea Origen: ['1900', '0s3hLSHmF9JBS7bNrx1jRd', 'Ali Farka Touré;Toumani Diabaté', 'Ali & Toumani', 'Kana Kassy', '8', '250013', 'False', '0.583', '0.44', '11', '-8.75', '1', '0.0313', '0.803', '0.813', '0.105', '0.594', '101.799', '4', 'afrobeat']
# Linea Origen: ['1901', '6yM82PxMywRHehdoQgQT8p', 'Bola Johnson', 'Man No Die', 'Lagos Sisi', '44', '203040', 'False', '0.718', '0.626', '10', '-9.049', '0', '0.0604', '0.147', '0.00207', '0.0994', '0.662', '107.288', '4', 'afrobeat']
# Linea Origen: ['1902', '2yBjFF19OmukrC7deP7LfZ', 'Fela Kuti;Afrika 70', 'Expensive Shit', 'Expensive Shit', '36', '793200', 'False', '0.612', '0.876', '5', '-7.668', '0', '0.11', '0.22', '0.399', '0.0863', '0.677', '123.866', '4', 'afrobeat']
# Linea Origen: ['1903', '4PqKGf9O8g1MiVDDDFBK6P', 'Azarel;Leor', 'Who Am I (Psalm 8:4)', 'Who Am I (Psalm 8:4)', '16', '182608', 'False', '0.733', '0.342', '9', '-15.834', '0', '0.284', '0.102', '0.00699', '0.146', '0.484', '184.058', '4', 'afrobeat']
# Linea Origen: ['1904', '59vZs9bJrEpBQHuK1M3tmS', 'The Bamboos;Washington', 'Medicine Man', 'The Wilhelm Scream', '47', '268040', 'False', '0.565', '0.621', '7', '-5.62', '1', '0.0264', '0.00773', '0.0324', '0.257', '0.403', '150.036', '4', 'afrobeat']
# Linea Origen: ['1905', '56YQC28RHtv9Wc5x3NCmYd', 'Edem Evangelist', 'Knocking on Your Door', 'Knocking on Your Door', '16', '194403', 'False', '0.696', '0.769', '6', '-4.457', '1', '0.0433', '0.553', '0.16', '0.325', '0.896', '98.031', '4', 'afrobeat']
# Linea Origen: ['1906', '5JT2sFsiVIlHOKABecgyR5', 'Nkumba System;Mamani Keïta', 'Paisano', 'Paisano', '16', '238201', 'False', '0.66', '0.717', '7', '-10.441', '1', '0.0559', '0.407', '4.44e-05', '0.0536', '0.964', '165.259', '3', 'afrobeat']
# ...
# Linea Origen: ['6654', '1eJWO5h4Prnu5aWZBhmawk', 'Darzamat', "Solfernus' Path", 'Pain Collector', '17', '238386', 'False', '0.513', '0.968', '4', '-4.002', '1', '0.217', '8.74e-06', '0.25', '0.37', '0.166', '115.014', '4', 'black-metal']
# Linea Origen: ['6655', '1X0hnY9QLx44Zl9BwKm0It', 'I AM', 'Hard 2 Kill', 'Steel Roses', '18', '330294', 'False', '0.354', '0.844', '4', '-4.28', '1', '0.0579', '0.000605', '0.468', '0.111', '0.0723', '139.964', '4', 'black-metal']
# Linea Origen: ['6656', '0eTQYv3sPn3uOlRCxhfNb9', 'Manes', 'Be All End All', 'Ars Moriendi - The Lower Crown', '17', '222000', 'False', '0.551', '0.574', '11', '-9.539', '0', '0.0334', '0.000697', '0.399', '0.0994', '0.0719', '120.081', '4', 'black-metal']
# Linea Origen: ['6657', '45znDER6ghdltzbU6EyvPR', 'Unanimated', 'Ancient God Of Evil', 'Eye Of The Greyhound', '18', '271413', 'False', '0.253', '0.956', '7', '-6.385', '1', '0.157', '2.54e-05', '0.00612', '0.44', '0.126', '129.066', '4', 'black-metal']
# Linea Origen: ['6658', '1vjBp7gAe2uxGWLeYL2s86', 'Cruachan', 'The Middle Kingdom', 'Celtica (Voice of Morrigan)', '17', '338040', 'False', '0.318', '0.696', '4', '-9.243', '0', '0.0442', '0.0189', '0.321', '0.0756', '0.216', '180.298', '4', 'black-metal']
# Linea Origen: ['6659', '79u7sIEIYPZ549jpH9FggZ', 'Isengard', 'Vårjevndøgn', 'Rockemillion', '17', '128039', 'False', '0.157', '0.94', '11', '-7.582', '0', '0.0966', '0.00159', '0.905', '0.445', '0.238', '155.425', '4', 'black-metal']
# Linea Origen: ['6660', '1oNgtfuBBsQP30U4B5N60w', 'Manes', 'Slow Motion Death Sequence', 'Poison Enough for Everyone', '17', '273066', 'False', '0.534', '0.759', '6', '-8.391', '0', '0.0435', '0.0125', '0.477', '0.61', '0.141', '119.924', '4', 'black-metal']
# Linea Origen: ['6661', '4Iiylqe2XjsQQqGSJ90QhB', 'Cradle Of Filth', 'Existence Is Futile', 'Necromantic Fantasies', '41', '340769', 'False', '0.493', '0.969', '10', '-6.061', '0', '0.0689', '2.28e-05', '0.385', '0.15', '0.224', '110.071', '4', 'black-metal']
# Linea Origen: ['6662', '52KUWZO1AdRXIaIaKZor0R', 'Hypocrisy', 'Abducted', 'Abducted', '19', '170546', 'False', '0.175', '0.95', '7', '-7.358', '1', '0.121', '0.0', '0.846', '0.322', '0.125', '119.416', '4', 'black-metal']
# Linea Origen: ['6663', '09m9jUkYKbSg51QRmIMb29', 'Whoredom Rife', 'Dommedagskvad', 'Cursing the Storm to Come', '17', '302851', 'False', '0.0698', '0.898', '0', '-5.577', '1', '0.0882', '1.02e-05', '0.000406', '0.12', '0.0326', '179.84', '3', 'black-metal']
# Linea Origen: ['6664', '0Fzw0tKc6n5PzjcgXtZFdZ', 'Division Speed', 'Division Speed', 'Snowstorm over Narvik', '19', '179600', 'False', '0.161', '0.927', '7', '-6.795', '1', '0.0819', '7.38e-05', '0.539', '0.524', '0.0838', '110.35', '5', 'black-metal']
# Linea Origen: ['6665', '3e0tyTV5FiV1bcYeRjdDz2', 'Moonspell', 'Sin / Pecado', 'The Hanged Man', '18', '386333', 'False', '0.404', '0.636', '4', '-8.798', '0', '0.0325', '0.0643', '0.653', '0.0795', '0.0979', '140.105', '4', 'black-metal']
# Linea Origen: ['6666', '5S98MKSX7MJKmLTyvNXdg9', 'Hecate Enthroned', 'The Slaughter of Innocence, A Requiem for the Mighty', 'Beneath a December Twilight', '17', '410533', 'False', '0.204', '0.86', '8', '-12.73', '1', '0.0542', '3.41e-05', '0.886', '0.311', '0.0832', '131.587', '4', 'black-metal']
# Linea Origen: ['6667', '7BNlY7buAtaFvqhXKs6uGV', 'Moonspell', '1755', '1 De Novembro', '18', '233680', 'False', '0.452', '0.977', '9', '-3.574', '0', '0.0655', '6.24e-06', '0.734', '0.167', '0.324', '130.013', '4', 'black-metal']
# Linea Origen: ['6668', '49kSKso3XFKUaKp349xwBY', 'Månegarm', 'Dödsfärd', 'I evig tid', '18', '148981', 'False', '0.287', '0.921', '7', '-6.142', '0', '0.059', '0.000147', '0.0', '0.216', '0.559', '89.945', '4', 'black-metal']
# Linea Origen: ['6669', '0P5eb6K1JqpTE2u3qRQSRf', 'Warmoon Lord', 'Battlespells', 'In Perennial Twilight', '17', '485917', 'False', '0.114', '0.808', '1', '-13.192', '1', '0.0534', '1.62e-06', '0.225', '0.313', '0.0487', '159.719', '4', 'black-metal']
# Linea Origen: ['6670', '3Trr6zejOUebGpiTY3ZF5N', 'Primordial', "Redemption at the Puritan's Hand", 'Bloodied Yet Unbowed', '17', '527080', 'False', '0.226', '0.827', '8', '-8.358', '0', '0.0521', '2.76e-05', '0.103', '0.106', '0.284', '108.142', '4', 'black-metal']
# Linea Origen: ['6671', '1zkGkQ3z8Hv7HMwINGg19B', 'Impaled Nazarene', 'All That You Fear', 'Armageddon Death Squad', '44', '175293', 'False', '0.22', '0.984', '9', '-4.698', '0', '0.113', '1.07e-06', '0.933', '0.0544', '0.125', '184.908', '4', 'black-metal']
# Linea Origen: ['6672', '2jRgjgIPMUbCvWBOVUEDRU', "Mord'a'Stigmata", 'Dreams of Quiet Places', 'Exiles', '17', '377457', 'False', '0.188', '0.982', '4', '-5.187', '0', '0.114', '7.33e-05', '0.816', '0.592', '0.0392', '131.964', '4', 'black-metal']
# Linea Origen: ['6673', '5hduHc1QcT6s2MuJPQv2I6', 'Hypocrisy', 'Virus', 'Compulsive Psychosis', '18', '254506', 'False', '0.303', '0.971', '6', '-3.826', '1', '0.0852', '2.55e-06', '0.594', '0.354', '0.14', '179.972', '4', 'black-metal']
# Linea Origen: ['6674', '2kjzqEAuCR3Q9a0MGn1KEK', 'Negator', 'Panzer Metal', 'Feuersturm', '16', '213813', 'False', '0.321', '0.989', '8', '-3.111', '0', '0.0764', '1.33e-06', '0.836', '0.363', '0.0395', '109.701', '4', 'black-metal']
# Linea Origen: ['6675', '1t1trD4LtJ2U3n8dzQAoR2', 'Marduk', "Here's No Peace", 'Woman of Dark Desires', '17', '270213', 'False', '0.11', '0.972', '8', '-5.783', '0', '0.0719', '2.95e-06', '1.72e-05', '0.296', '0.156', '174.131', '4', 'black-metal']
# Linea Origen: ['6676', '5Re6Qmv5A7XuomapVBxxyf', 'Aversions Crown', 'Tyrant', 'Xenoforms', '19', '251893', 'True', '0.527', '0.979', '1', '-3.508', '1', '0.208', '8.46e-05', '0.0444', '0.177', '0.131', '129.949', '4', 'black-metal']
# Linea Origen: ['6677', '3hErTEgACWJyUsRDSNQcDE', 'Watain', 'TRIDENT WOLF ECLIPSE', 'Ultra (Pandemoniac)', '17', '241340', 'False', '0.341', '0.946', '7', '-11.377', '1', '0.0665', '3.32e-06', '0.912', '0.066', '0.064', '141.006', '4', 'black-metal']
# Linea Origen: ['6678', '1EcNJPxbjvi4HJ0iPBDkJp', 'Aversions Crown', 'Hell Will Come for Us All', 'Hymn of Annihilation', '19', '271097', 'False', '0.423', '0.978', '10', '-4.076', '1', '0.131', '0.00165', '7.22e-05', '0.301', '0.0413', '120.009', '4', 'black-metal']
# Linea Origen: ['6679', '7wpxUFLO2n6zKzIIQk6Dbd', 'Månegarm', 'Fornaldarsagor', 'Slaget vid Bråvalla', '18', '302635', 'False', '0.425', '0.964', '10', '-3.955', '0', '0.0676', '3.87e-06', '0.000957', '0.0724', '0.152', '140.024', '4', 'black-metal']
# Linea Origen: ['6680', '4OAgWmisw29lzun5bfaUeV', 'Craft', 'White Noise and Black Metal', 'Darkness Falls', '17', '290400', 'False', '0.107', '0.99', '8', '-5.61', '1', '0.103', '4.47e-06', '0.274', '0.342', '0.186', '181.558', '3', 'black-metal']
# Linea Origen: ['6681', '7rQppQkXdaEbQI4wq22I7X', 'Hypocrisy', 'The Fourth Dimension / Maximum Abduction', 'Reborn', '19', '188000', 'False', '0.315', '0.948', '8', '-7.621', '1', '0.102', '9.69e-05', '0.198', '0.326', '0.318', '113.139', '4', 'black-metal']
# Linea Origen: ['6682', '7rXYrysPjh6AHwV2rb2lD5', 'Hypocrisy', 'Virus', "Incised Before I've Ceased", '19', '268506', 'False', '0.455', '0.978', '1', '-5.072', '1', '0.0895', '1.38e-06', '0.711', '0.211', '0.141', '100.018', '4', 'black-metal']
# Linea Origen: ['6683', '4FyflphvUqX71jrNDqTg4J', 'Witchery', "In His Infernal Majesty's Service", 'Feed the Gun', '17', '182600', 'False', '0.375', '0.998', '2', '-2.688', '1', '0.0952', '1.26e-05', '0.00114', '0.223', '0.152', '169.939', '4', 'black-metal']
# Linea Origen: ['6684', '5nLRIVvALv61Qc1H9enDWB', 'Hypocrisy', 'A Taste of Extreme Divinity', 'Solar Empire', '19', '315786', 'False', '0.127', '0.983', '1', '-3.909', '1', '0.109', '2.28e-06', '0.675', '0.33', '0.0585', '97.631', '1', 'black-metal']
# Linea Origen: ['6685', '0VC0DRLD9ZkiWZJFZ3AFL3', 'Enslaved', 'Riitiir', 'Veilburner', '17', '405626', 'False', '0.436', '0.93', '2', '-6.227', '1', '0.0498', '2.12e-06', '0.0245', '0.263', '0.332', '120.038', '4', 'black-metal']
# Linea Origen: ['6686', '0msv1I9EMsPZ0NK4pcgtEq', 'Inquisition', 'Invoking the Majestic Throne of Satan', 'Invoking the Majestic Throne of Satan', '17', '334040', 'False', '0.204', '0.962', '7', '-5.079', '1', '0.0941', '0.00134', '0.929', '0.0513', '0.138', '140.079', '4', 'black-metal']
# Linea Origen: ['6687', '0aX0erB1ApGCvLtDoX2p6h', 'Angelmaker', 'Twilight', 'The Great Grey Flame', '19', '214133', 'True', '0.504', '0.992', '7', '-1.9', '1', '0.122', '0.000112', '2.54e-06', '0.392', '0.235', '119.975', '4', 'black-metal']
# Linea Origen: ['6688', '0OI2KyCy0TZnPeLadtl6sI', 'Månegarm', 'Ynglingaättens Öde', 'The Wolfheart (English Version)', '17', '295093', 'False', '0.251', '0.96', '10', '-4.424', '0', '0.0664', '2.53e-05', '0.017', '0.0795', '0.179', '105.734', '1', 'black-metal']
# Linea Origen: ['6689', '5IXtD2TsspSRVym4DVgdt8', 'Inquisition', 'Black Mass for a Mass Grave', 'Extinction of Darkness and Light', '17', '339358', 'True', '0.292', '0.984', '0', '-5.373', '1', '0.106', '3.51e-05', '0.211', '0.202', '0.0358', '129.835', '4', 'black-metal']
# Linea Origen: ['6690', '4Xjj5GXm3uQGtkHmmWrLR2', 'Cradle Of Filth', 'Damnation And A Day', 'Thank God For The Suffering', '17', '373320', 'False', '0.381', '0.976', '5', '-4.982', '0', '0.108', '0.000159', '0.0164', '0.539', '0.207', '161.057', '4', 'black-metal']
# Linea Origen: ['6691', '5stvXtndN1qb5ZjfNgvP34', 'Hypocrisy', 'Virus', 'Craving for Another Killing', '19', '230160', 'False', '0.441', '0.996', '1', '-4.058', '0', '0.157', '1.17e-06', '0.00376', '0.337', '0.0861', '114.968', '4', 'black-metal']
# Linea Origen: ['6692', '11SMSHxTMXx5y1IJQ4Lj79', 'Kvelertak', 'Nattesferd', 'Bronsegud', '18', '177506', 'False', '0.217', '0.975', '4', '-5.444', '0', '0.103', '6.11e-06', '0.384', '0.371', '0.39', '185.284', '4', 'black-metal']
# Linea Origen: ['6693', '3D0xB8fSqMyycALgNMpxwM', 'Moonspell', 'From Down Below - Live 80 Meters Deep', 'Without Rule - Live 80 Meters Deep', '18', '489000', 'False', '0.367', '0.879', '0', '-7.413', '1', '0.0742', '0.000555', '0.698', '0.963', '0.102', '139.879', '4', 'black-metal']
# Linea Origen: ['6694', '0y5Rpnq7cT4FA4sbPLMkWo', 'Kvelertak', 'Meir', 'Undertro', '18', '385853', 'False', '0.469', '0.956', '9', '-5.665', '1', '0.104', '4.3e-05', '0.842', '0.329', '0.175', '139.975', '4', 'black-metal']
# Linea Origen: ['6695', '6iqQX4KlFL28KMqiEFMWCQ', 'Hypocrisy', 'The Final Chapter', 'A Coming Race', '19', '308533', 'False', '0.173', '0.89', '4', '-7.81', '0', '0.0672', '1.52e-06', '0.822', '0.237', '0.091', '120.008', '4', 'black-metal']
# Linea Origen: ['6696', '5nYxvboEEXpXPxyrUTrtya', 'Darkthrone', 'Hate Them', 'Det Svartner Nå', '17', '338173', 'False', '0.288', '0.992', '1', '-4.202', '1', '0.0808', '1.7e-05', '0.279', '0.12', '0.0599', '126.17', '4', 'black-metal']
# Linea Origen: ['6697', '6dUcAl6CAbimvdvJ6tM4WK', 'Portrayal of Guilt', 'Let Pain Be Your Guide', 'Your War', '19', '139840', 'False', '0.254', '0.959', '10', '-4.848', '0', '0.0815', '0.00131', '0.298', '0.253', '0.182', '98.506', '4', 'black-metal']
# Linea Origen: ['6698', '2VgyA66xbFdyZ2gBulBA4O', 'Månegarm', 'Månegarm', 'Mother Earth Father Thunder - Bonus Track', '18', '368250', 'False', '0.424', '0.594', '0', '-8.637', '0', '0.0391', '0.00897', '0.056', '0.162', '0.17', '130.001', '4', 'black-metal']
# Linea Origen: ['6699', '3IXIgLjDHoVW7DOsvJKS2a', 'Entombed', 'Uprising', "Wont't Back Down", '18', '194080', 'False', '0.0806', '0.962', '7', '-2.794', '1', '0.0908', '1.26e-05', '8.22e-05', '0.137', '0.237', '171.653', '4', 'black-metal']
# Linea Origen: ['6700', '3D6ZPZrFk2CHZCJ2STxHW7', 'Deicide', 'In the Minds of Evil', 'In the Minds of Evil', '46', '233048', 'False', '0.535', '0.889', '10', '-5.547', '0', '0.0533', '9.92e-05', '0.41', '0.329', '0.327', '97.493', '4', 'black-metal']
# Linea Origen: ['6701', '4sRWnJytz2RrLZgl1kMlRL', 'Alcest', 'Kodama', 'Eclosion', '35', '534826', 'False', '0.452', '0.553', '0', '-9.464', '0', '0.0311', '0.00118', '0.767', '0.0861', '0.111', '142.589', '4', 'black-metal']
# Linea Origen: ['6702', '3pLd1F8k6ozsPLRutH87iy', 'Belphegor', 'Conjuring the Dead', 'Conjuring the Dead', '42', '273715', 'False', '0.462', '0.968', '0', '-5.117', '1', '0.156', '1.24e-05', '0.603', '0.0631', '0.0418', '124.945', '4', 'black-metal']
# Linea Origen: ['6703', '4Ig4lqvambqo9NPYoDklJe', 'Alcest', 'Shelter (Deluxe Edition)', 'La nuit marche avec moi', '34', '298080', 'False', '0.467', '0.814', '8', '-4.917', '0', '0.0338', '0.0362', '0.17', '0.147', '0.321', '126.014', '4', 'black-metal']
# Linea Origen: ['6704', '3gq4nxtnH8HPLj6GgDD4xD', 'Moribund Oblivion', 'Manevi', 'Gecip Gittim', '18', '301413', 'False', '0.455', '0.758', '3', '-5.164', '0', '0.0428', '1.33e-05', '0.0503', '0.0898', '0.273', '140.061', '4', 'black-metal']
# Linea Origen: ['6705', '3AUAvzhXxyTerHasVjjVGc', 'Behemoth', 'The Satanist', 'Ben Sahar', '36', '334986', 'True', '0.2', '0.954', '1', '-4.717', '1', '0.121', '1.89e-05', '0.0139', '0.114', '0.102', '112.063', '4', 'black-metal']
# Linea Origen: ['6706', '2gCqYL6CgWs0ICgIoyJtkV', 'Deadlife', 'Where Life Ends', "Please Don't Save Me", '18', '402087', 'False', '0.274', '0.219', '7', '-13.748', '0', '0.0366', '0.88', '0.818', '0.0879', '0.24', '79.84', '4', 'black-metal']
# Linea Origen: ['6707', '0VZAhuEaRQbBUOpYJU9I0Y', 'Gorgoroth', 'Instinctus Bestialis', 'Radix Malorum', '40', '193773', 'False', '0.316', '0.858', '2', '-4.034', '1', '0.0613', '2.43e-06', '0.675', '0.138', '0.306', '104.826', '5', 'black-metal']
# Linea Origen: ['6708', '7bj7MeJ2P5SYUyA1cSwZgl', 'Ajattara', 'Itse', 'Yhdeksäs', '18', '283400', 'False', '0.416', '0.936', '5', '-5.037', '0', '0.0706', '8.56e-06', '0.00972', '0.285', '0.13', '142.464', '3', 'black-metal']
# Linea Origen: ['6709', '4XeacvPPCoh3siE3kYt6QQ', 'Arkona', 'Lunaris', 'Lunaris', '17', '397000', 'False', '0.301', '0.892', '0', '-7.302', '1', '0.105', '0.000106', '0.817', '0.175', '0.0375', '120.081', '4', 'black-metal']
# Linea Origen: ['6710', '5wvC3BZ2sIGSN7FGHjqVUL', 'Shade Empire', 'Omega Arcane', 'Malicious Winds', '18', '320600', 'False', '0.497', '0.939', '1', '-5.595', '1', '0.0635', '2.04e-06', '0.967', '0.3', '0.327', '120.04', '4', 'black-metal']
# Linea Origen:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-02ec5bf3897b> in <cell line: 2>()
#       4     next(spamreader) #Tema cursores, ficheros y cabecera CSV...
#       5     for lineaOrigen in spamreader:
# ----> 6         print('Linea Origen:', lineaOrigen)
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.9/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.9/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Paso 3
#
# Ahora toca unir el paso 1 y 2. ¿Se te ocurre cómo?
#
# > **Ejercicio**: Completa este paso tú mismo.

# %%
# <SOL>
with open('dataset.csv', newline='') as csvfile:
  spamreader = csv.reader(csvfile, delimiter=',') #delimiter = Separadoe
  next(spamreader) #Tema cursores, ficheros y cabecera CSV...
  for lineaOrigen in spamreader:  
    #Pego el código que me interesa...
    numArtistas = 1
    if (len( lineaOrigen[2].split(';') ) > 0 ):
      numArtistas = len( lineaOrigen[2].split(';') ) 

    explicito = lineaOrigen[7]
    if(explicito[0] == 'T'):
        explicito = -1
    elif(explicito[0] == 'F'):
        explicito = 1
    else:
      explicito = 0

    tempo = float(lineaOrigen[-3])
    if(tempo == 128):
      tempo = 10
    elif(tempo > 120):
      tempo = 1
    elif(tempo <= 120 and tempo > 100):
      tempo = 0
    elif(tempo <= 100):
      tempo = -1

    popularidad = int(lineaOrigen[5]) / 100

    duracion = int(lineaOrigen[6]) / (60 * 1000) 

    polaridad = (float(lineaOrigen[8]) + float(lineaOrigen[11]) + float(lineaOrigen[13]) )/3 

    genero = lineaOrigen[-1]

    lineaDestino = [numArtistas, popularidad, duracion, explicito, polaridad, tempo, genero]

    print('Linea Destino:', lineaDestino)

#</SOL>
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3d93170d3f21> in <cell line: 2>()
#       1 # <SOL>
#       2 with open('dataset.csv', newline='') as csvfile:
# ----> 3   spamreader = csv.reader(csvfile, delimiter=',') #delimiter = Separadoe
#       4   next(spamreader) #Tema cursores, ficheros y cabecera CSV...
#       5   for lineaOrigen in spamreader:
#
# NameError: name 'csv' is not defined

# %% [markdown]
# ### Paso 4
#
# Juntamos el paso 3 con el escribir en un nuevo fichero al mismo tiempo.

# %%
import csv 
with open('SpotyDASH.csv', 'w', newline='') as csvfile: #El CSV no se puede llamar igual
  spotiWriter = csv.writer(csvfile, delimiter=',')

  spotiWriter.writerow( ['numArtistas', 'popularidad', 'duracion', 'explicito', 'polaridad', 'tempo', 'genero'] )


  #TABULAMOS TODO DE PASO 3... 
  #<SOL>
  with open('dataset.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',') #delimiter = Separadoe
    next(spamreader) #Tema cursores, ficheros y cabecera CSV...
    for lineaOrigen in spamreader:  
      #Pego el código que me interesa...
      numArtistas = 1
      if (len( lineaOrigen[2].split(';') ) > 0 ):
        numArtistas = len( lineaOrigen[2].split(';') ) 

      explicito = lineaOrigen[7]
      if(explicito[0] == 'T'):
          explicito = -1
      elif(explicito[0] == 'F'):
          explicito = 1
      else:
        explicito = 0

      tempo = float(lineaOrigen[-3])
      if(tempo == 128):
        tempo = 10
      elif(tempo > 120):
        tempo = 1
      elif(tempo <= 120 and tempo > 100):
        tempo = 0
      elif(tempo <= 100):
        tempo = -1

      popularidad = int(lineaOrigen[5]) / 100

      duracion = int(lineaOrigen[6]) / (60 * 1000) 

      polaridad = (float(lineaOrigen[8]) + float(lineaOrigen[11]) + float(lineaOrigen[13]) )/3 

      genero = lineaOrigen[-1]

      lineaDestino = [numArtistas, popularidad, duracion, explicito, polaridad, tempo, genero]

      #</SOL>
      spotiWriter.writerow( lineaDestino ) #AÑADIMOS EL WRITEROW()
  


      #</SOL>
      spotiWriter.writerow( lineaDestino ) #AÑADIMOS EL WRITEROW()

# %% [markdown]
# > **Ejercicio**: Para acabar, busca tu fichero generado, descárgalo y comprueba que todo está como esperábamos.
